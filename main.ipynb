# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader

# %%
# reload modules
from importlib import reload

from utils.utils import find_subfolders
from utils.custom_data_loader import load_data

from utils.const import *

# %%
import os
import time



time = time.strftime("%Y%m%d%H%M%S", time.localtime())
save_path = r".\outputs" + "\\" + time

# create the directory
try:
    os.makedirs(save_path)
except FileExistsError:
    pass

# choose the device
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

def train_classifier(model, train_loader, val_loader, epochs=100, lr=0.0001, patience=10, device='cuda'):
    """
    Train a classification model with early stopping based on validation loss.

    Args:
        model (nn.Module): The classification model to train.
        train_loader (DataLoader): DataLoader for training data, yielding (inputs, labels).
        val_loader (DataLoader): DataLoader for validation data, yielding (inputs, labels).
        epochs (int): Maximum number of training epochs.
        lr (float): Learning rate for the optimizer.
        patience (int): Number of epochs to wait for improvement before early stopping.
        device (str): Device to train the model on ('cuda' or 'cpu').

    Returns:
        nn.Module: The trained model with the best validation performance.
        list: Training loss history.
        list: Validation loss history.
        list: Validation accuracy history.
    """
    # Define the loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    model.to(device)

    best_val_loss = float('inf')
    best_model_wts = None
    epochs_no_improve = 0

    train_losses = []
    val_losses = []
    val_accuracies = []

    for epoch in range(epochs):
        # Training Phase
        model.train()
        running_loss = 0.0
        for batch in train_loader:
            inputs, labels = batch  # Assuming each batch is a tuple (inputs, labels)
            inputs = inputs.to(device).float()
            labels = labels.to(device).long()

            optimizer.zero_grad()
            outputs = model(inputs, modes=('lightweight', 'moderate', 'advanced'))  # Outputs are logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # Validation Phase
        model.eval()
        val_running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0
        with torch.no_grad():
            for batch in val_loader:
                inputs, labels = batch
                inputs = inputs.to(device).float()
                labels = labels.to(device).long()

                outputs = model(inputs, modes=('lightweight', 'moderate', 'advanced'))
                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * inputs.size(0)

                # Calculate accuracy
                _, preds = torch.max(outputs, 1)
                correct_predictions += torch.sum(preds == labels)
                total_predictions += labels.size(0)

        epoch_val_loss = val_running_loss / len(val_loader.dataset)
        epoch_val_accuracy = correct_predictions.double() / total_predictions
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_accuracy.item())

        print(f"Epoch {epoch + 1}/{epochs}, "
              f"Train Loss: {epoch_train_loss:.4f}, "
              f"Val Loss: {epoch_val_loss:.4f}, "
              f"Val Accuracy: {epoch_val_accuracy:.4f}")

        # Early Stopping Check
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            best_model_wts = model.state_dict()
            epochs_no_improve = 0
            print("Validation loss decreased, saving the model...")
        else:
            epochs_no_improve += 1
            print(f"No improvement in validation loss for {epochs_no_improve} epoch(s).")
            if epochs_no_improve >= patience:
                print("Early stopping triggered.")
                break

    # Load the best model weights
    if best_model_wts is not None:
        model.load_state_dict(best_model_wts)

    return model, train_losses, val_losses, val_accuracies


def evaluate_classifier(model, test_loader, device='cuda'):
    """
    Evaluate a classification model on test data.

    Args:
        model (nn.Module): The trained classification model.
        test_loader (DataLoader): DataLoader for test data, yielding (inputs, labels).
        device (str): Device to perform evaluation on ('cuda' or 'cpu').

    Returns:
        float: Mean test loss.
        float: Test accuracy.
        list: List of reconstruction (classification) errors per sample.
        torch.Tensor: Model outputs for the last batch.
    """
    criterion = nn.CrossEntropyLoss()
    model.to(device)
    test_loss = 0.0
    correct = 0
    total = 0
    classification_errors = []
    all_outputs = []
    all_labels = []
    with torch.no_grad():
        for batch in test_loader:
            inputs, labels = batch
            inputs = inputs.to(device).float()
            labels = labels.to(device).long()

            outputs = model(inputs, modes=('lightweight', 'moderate', 'advanced'))  # [batch_size, num_classes]
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)

            # Calculate accuracy
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels)
            total += labels.size(0)

            # Collect classification errors (optional)
            # Here, we can define error as 1 - accuracy per sample, but CrossEntropyLoss is not per-sample
            # Alternatively, collect whether each sample was correctly classified
            errors = (preds != labels).float().cpu().numpy()
            classification_errors.extend(errors)

            # Optionally, collect all outputs and labels
            all_outputs.append(outputs.cpu())
            all_labels.append(labels.cpu())

    mean_test_loss = test_loss / len(test_loader.dataset)
    test_accuracy = correct.double() / total
    return mean_test_loss, test_accuracy.item(), classification_errors, torch.cat(all_outputs, dim=0)

# %%
root_directory = r"/Users/zeeshawnh/College/GuoResearch/Transformer/data/physionet.org/files/challenge-2021/1.0.3/training"
dataset_paths = find_subfolders(root_directory)[0:1]
print(dataset_paths)

overlap = 1
lead_num = 1
cycle_num = 2

df_all, period_list = load_data(dataset_paths, lead_num=lead_num, max_circle=None,
                        cycle_num=cycle_num, overlap=overlap)  # abnormal or single_abnormal
# print("Data loaded. Datasets loaded: ", loaded_paths_abnormal)
print(f"Number of cycles: {len(df_all)}")
print(df_all.head())
# Out:
# ['/Users/zeeshawnh/College/GuoResearch/Transformer/data/physionet.org/files/challenge-2021/1.0.3/training/ningbo']
# Number of records: 16905
# Number of cycles: 180627
#    diagnosis  lead_point_1  lead_point_2  lead_point_3  lead_point_4  \
# 0          1    489.291929    379.655570    317.030375    199.583311
# 1          1    547.392657    437.024567    265.922540    141.760389
# 2          1    484.515475    457.125250    307.673652    207.025858
# 3          1    605.671097    514.210476    411.820906    275.221931
# 4          1    468.801768    433.948417    316.163597    210.350122
#
#    lead_point_5  lead_point_6  lead_point_7  lead_point_8  lead_point_9  ...  \
# 0    109.895788    -15.519290    -29.074766    -41.901487    -34.657169  ...
# 1    124.628337     67.162338     32.779171     -2.024886      1.708591  ...
# 2    102.278719     11.732221     -6.441590    -31.976693    -68.912492  ...
# 3    124.027387     39.355392     46.045898     53.142635     29.494930  ...
# 4     59.949343     21.097848     36.836905    -75.187833    -68.079481  ...
#
#    lead_point_505  lead_point_506  lead_point_507  lead_point_508  \
# 0     -124.639534     -131.996010     -107.389054        7.863044
# 1     -133.970804     -128.970084       -3.682476       49.129766
# 2     -182.289075     -133.995683      -55.159715        4.700974
# 3     -181.109584     -162.534583     -111.122834      -32.734418
# 4     -151.706246     -167.600958     -121.858665      -49.242246
#
#    lead_point_509  lead_point_510  lead_point_511  lead_point_512  \
# 0       97.917235      314.594256      405.902184      529.293604
# 1      135.126152      316.477066      427.392962      528.369364
# 2      162.851389      256.176235      397.229978      472.926422
# 3       97.568758      273.614601      341.009814      448.254993
# 4      129.158330      248.213837      341.461017      454.905019
#
#    cycle_duration_1  cycle_duration_2
# 0             0.822             0.828
# 1             0.828             0.844
# 2             0.844             0.846
# 3             0.846             0.828
# 4             0.828             0.836
#
# [5 rows x 515 columns]

# %%
print(df_all.columns[-25:])
# Out:
# Index(['lead_point_490', 'lead_point_491', 'lead_point_492', 'lead_point_493',
#        'lead_point_494', 'lead_point_495', 'lead_point_496', 'lead_point_497',
#        'lead_point_498', 'lead_point_499', 'lead_point_500', 'lead_point_501',
#        'lead_point_502', 'lead_point_503', 'lead_point_504', 'lead_point_505',
#        'lead_point_506', 'lead_point_507', 'lead_point_508', 'lead_point_509',
#        'lead_point_510', 'lead_point_511', 'lead_point_512',
#        'cycle_duration_1', 'cycle_duration_2'],
#       dtype='object')

# %%
print(period_list[0:5])
# Out:
# [np.float64(0.822), np.float64(0.828), np.float64(0.828), np.float64(0.844), np.float64(0.844)]

# %%
print(df_all.iloc[:5, -2:])
# Out:
#    cycle_duration_1  cycle_duration_2
# 0             0.822             0.828
# 1             0.828             0.844
# 2             0.844             0.846
# 3             0.846             0.828
# 4             0.828             0.836

# %%
# Calculate the 33rd and 66th percentiles (the thresholds)
threshold1 = np.percentile(period_list, 33)
threshold2 = np.percentile(period_list, 66)
print(threshold1) # 70 bpm
print(threshold2) # 90 bpm
# Out:
# 0.6
# 0.916

# %%
# Assuming period_list is currently a Python list
period_list = np.array(period_list)  # Convert to a NumPy array

# Split the array based on these thresholds
group1 = period_list[period_list < threshold1]  # Group 1: durations below threshold1
group2 = period_list[(period_list >= threshold1) & (period_list < threshold2)]  # Group 2: durations between threshold1 and threshold2
group3 = period_list[period_list >= threshold2]  # Group 3: durations above threshold2

# Print the sizes of the groups
print(len(group1))
print(len(group2))
print(len(group3))
# Out:
# 118902
# 118958
# 123394

# %%
import pandas as pd
from itertools import chain
import torch
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Get all unique diagnosis codes
all_codes = set(df_all['diagnosis'])

print(df_all['diagnosis'])

# Map diagnosis codes to integer labels
code_to_label = {code: idx for idx, code in enumerate(sorted(all_codes))}

print(code_to_label)

# Assign labels to the data
df_all['label'] = df_all['diagnosis'].apply(lambda x: code_to_label[x])
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 180622    1
# 180623    1
# 180624    1
# 180625    1
# 180626    1
# Name: diagnosis, Length: 180627, dtype: int64
# {1: 0, 2: 1, 3: 2, 5: 3}

# %%
print(df_all.head())
# Out:
#    diagnosis  lead_point_1  lead_point_2  lead_point_3  lead_point_4  \
# 0          2    919.118407    841.471860    621.391833    392.220564
# 1          2    923.504002    870.761209    694.410731    469.905147
# 2          2    880.194707    781.914958    591.801097    353.823836
# 3          2    942.919682    901.353414    703.133028    472.880977
# 4          2    905.630213    793.383711    601.627484    383.681014
#
#    lead_point_5  lead_point_6  lead_point_7  lead_point_8  lead_point_9  ...  \
# 0    140.411173     87.756127     59.186980     47.038341     25.760808  ...
# 1    199.830808     68.375789     61.196152     27.701447     13.033223  ...
# 2    102.872101     42.169220     23.550116      7.127889    -16.700671  ...
# 3    198.257330     89.649529     74.757633     34.833066     14.175182  ...
# 4    142.028472     61.823344     40.290861     26.333055     33.789110  ...
#
#    lead_point_506  lead_point_507  lead_point_508  lead_point_509  \
# 0     -145.268249      -99.658548      -32.137554      146.783577
# 1     -117.212968      -84.606147      -20.491243      141.025840
# 2      -99.262426      -69.812719       -2.911967      164.472815
# 3     -119.007543      -86.005951       -5.115473      181.023400
# 4     -124.468925      -81.098960      -11.549326      163.438466
#
#    lead_point_510  lead_point_511  lead_point_512  cycle_duration_1  \
# 0      410.797999      626.839435      788.926980             1.136
# 1      414.608151      639.905977      831.433146             1.100
# 2      406.471386      616.595777      803.232835             1.128
# 3      433.574345      638.210617      811.244016             1.118
# 4      429.600802      652.977068      858.048589             1.104
#
#    cycle_duration_2  label
# 0             1.100      1
# 1             1.128      1
# 2             1.118      1
# 3             1.104      1
# 4             1.142      1
#
# [5 rows x 516 columns]

# %%
# Separate cycles, durations, and labels
# Assuming cycle columns are named as 'lead_point_1', 'lead_point_2', ..., and duration columns are 'cycle_duration_1', 'cycle_duration_2', etc.
cycle_columns = [col for col in df_all.columns if col.startswith('lead_point_')]
duration_columns = [col for col in df_all.columns if col.startswith('cycle_duration_')]

# Combine cycle data and duration as input features
X_cycles = df_all[cycle_columns].values  # Cycle features
X_durations = df_all[duration_columns].values  # Duration features

# Combine cycle and duration into a single feature array
X = np.hstack([X_cycles, X_durations])
y = df_all['label'].values

# Split data into training and test sets (stratify to preserve label distribution)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=23, stratify=y
)

print("Sample of X_train data:\n", X_train[:2])  # Print first two samples for verification
# Out:
# Sample of X_train data:
#  [[5.94218170e+02 6.81951674e+02 4.92837081e+02 ... 3.70766266e+02
#   8.18000000e-01 8.08000000e-01]
#  [3.66566269e+02 4.22801382e+02 3.95912344e+02 ... 1.48852281e+02
#   6.26000000e-01 5.68000000e-01]]

# %%
# Get the number of cycle points and duration columns
num_cycle_points = len(cycle_columns)
num_duration_columns = len(duration_columns)

# Scale the cycle data and duration separately
scaler_cycles = MinMaxScaler()
scaler_durations = MinMaxScaler()

X_train_cycles_scaled = scaler_cycles.fit_transform(X_train[:, :num_cycle_points])  # Scale cycle data
X_train_durations_scaled = scaler_durations.fit_transform(X_train[:, num_cycle_points:])  # Scale duration data

X_test_cycles_scaled = scaler_cycles.transform(X_test[:, :num_cycle_points])
X_test_durations_scaled = scaler_durations.transform(X_test[:, num_cycle_points:])

# Combine scaled cycle and duration features
X_train_scaled = np.hstack([X_train_cycles_scaled, X_train_durations_scaled])
X_test_scaled = np.hstack([X_test_cycles_scaled, X_test_durations_scaled])

# Further split training data into training and validation sets
X_train_scaled, X_val_scaled, y_train, y_val = train_test_split(
    X_train_scaled, y_train, test_size=0.2, random_state=23, stratify=y_train
)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# Optionally, expand dimensions if needed (e.g., for CNN input)
X_train_tensor = X_train_tensor.unsqueeze(1)  # Shape: (batch_size, 1, num_features)
X_val_tensor = X_val_tensor.unsqueeze(1)
X_test_tensor = X_test_tensor.unsqueeze(1)

# Create datasets
train_dataset = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = torch.utils.data.TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = torch.utils.data.TensorDataset(X_test_tensor, y_test_tensor)

# Create DataLoaders
train_batch_size = 64
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=train_batch_size, shuffle=True
)
val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=train_batch_size, shuffle=False
)
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=train_batch_size, shuffle=False
)

# %%
print("Shape of X_train_cycles:", X_train[:, :num_cycle_points].shape)
print("Shape of X_train_durations:", X_train[:, num_cycle_points:].shape)
print("Shape of X_test_cycles:", X_test[:, :num_cycle_points].shape)
print("Shape of X_test_durations:", X_test[:, num_cycle_points:].shape)

print("Shape of X_train_cycles:", X_train[:, :num_cycle_points].shape)
print("Shape of X_train_durations:", X_train[:, num_cycle_points:].shape)
print("Shape of X_test_cycles:", X_test[:, :num_cycle_points].shape)
print("Shape of X_test_durations:", X_test[:, num_cycle_points:].shape)

print("Scaled X_train_cycles sample:", X_train_cycles_scaled[:2])  # Print first two rows
print("Scaled X_train_durations sample:", X_train_durations_scaled[:2])

print("Shape of X_train_scaled:", X_train_scaled.shape)
print("Sample of X_train_scaled:", X_train_scaled[:2])  # Print first two rows

print("X_train_tensor dtype:", X_train_tensor.dtype, "shape:", X_train_tensor.shape)
print("y_train_tensor dtype:", y_train_tensor.dtype, "shape:", y_train_tensor.shape)

print("X_val_tensor dtype:", X_val_tensor.dtype, "shape:", X_val_tensor.shape)
print("y_val_tensor dtype:", y_val_tensor.dtype, "shape:", y_val_tensor.shape)

print("X_test_tensor dtype:", X_test_tensor.dtype, "shape:", X_test_tensor.shape)
print("y_test_tensor dtype:", y_test_tensor.dtype, "shape:", y_test_tensor.shape)

print("Unique labels in y_train:", np.unique(y_train))
print("Unique labels in y_val:", np.unique(y_val))
print("Unique labels in y_test:", np.unique(y_test))
# Out:
# Shape of X_train_cycles: (144501, 512)
# Shape of X_train_durations: (144501, 2)
# Shape of X_test_cycles: (36126, 512)
# Shape of X_test_durations: (36126, 2)
# Shape of X_train_cycles: (144501, 512)
# Shape of X_train_durations: (144501, 2)
# Shape of X_test_cycles: (36126, 512)
# Shape of X_test_durations: (36126, 2)
# Scaled X_train_cycles sample: [[0.21573086 0.23916599 0.291901   ... 0.44958366 0.2938349  0.30067804]
#  [0.19831059 0.21851534 0.28506194 ... 0.44979532 0.28448775 0.27926898]]
# Scaled X_train_durations sample: [[0.19011765 0.109435  ]
#  [0.14494118 0.07652222]]
# Shape of X_train_scaled: (115600, 514)
# Sample of X_train_scaled: [[0.2004449  0.21473398 0.27662894 ... 0.29471555 0.17835294 0.09681843]
#  [0.2243293  0.23602536 0.28938779 ... 0.31883605 0.23623529 0.13329676]]
# X_train_tensor dtype: torch.float32 shape: torch.Size([115600, 1, 514])
# y_train_tensor dtype: torch.int64 shape: torch.Size([115600])
# X_val_tensor dtype: torch.float32 shape: torch.Size([28901, 1, 514])
# y_val_tensor dtype: torch.int64 shape: torch.Size([28901])
# X_test_tensor dtype: torch.float32 shape: torch.Size([36126, 1, 514])
# y_test_tensor dtype: torch.int64 shape: torch.Size([36126])
# Unique labels in y_train: [0 1 2 3]
# Unique labels in y_val: [0 1 2 3]
# Unique labels in y_test: [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Print shapes of the datasets
print("Training data shape:", X_train.shape)
print("Validation data shape:", X_val_scaled.shape)
print("Test data shape:", X_test.shape)

# Print label distributions
unique, counts = np.unique(y_train, return_counts=True)
print("Training labels distribution:")
for label, count in zip(unique, counts):
    print(f"Label {label}: {count} samples")

unique, counts = np.unique(y_val, return_counts=True)
print("\nValidation labels distribution:")
for label, count in zip(unique, counts):
    print(f"Label {label}: {count} samples")

unique, counts = np.unique(y_test, return_counts=True)
print("\nTest labels distribution:")
for label, count in zip(unique, counts):
    print(f"Label {label}: {count} samples")

# Function to plot an ECG signal
def plot_ecg(signal, label, idx):
    
    plt.figure(figsize=(12, 4))
    plt.plot(signal)
    plt.title(f"ECG Signal {idx} - Label: {label}")
    plt.xlabel("Time (samples)")
    plt.ylabel("Amplitude (scaled)")
    plt.grid(True)
    plt.show()

# Plot first 5 samples from the training data
print("\nPlotting first 5 ECG signals from the training set:")
for i in range(5):
    signal = X_train[i]
    label = y_train[i]
    plot_ecg(signal, label, i)

# Plot first 5 samples from the test data
print("Plotting first 5 ECG signals from the test set:")
for i in range(5):
    signal = X_test[i]
    label = y_test[i]
    plot_ecg(signal, label, i)
# Out:
# Training data shape: (144501, 514)
# Validation data shape: (28901, 514)
# Test data shape: (36126, 514)
# Training labels distribution:
# Label 0: 40640 samples
# Label 1: 62343 samples
# Label 2: 11172 samples
# Label 3: 1445 samples
#
# Validation labels distribution:
# Label 0: 10160 samples
# Label 1: 15587 samples
# Label 2: 2793 samples
# Label 3: 361 samples
#
# Test labels distribution:
# Label 0: 12700 samples
# Label 1: 19483 samples
# Label 2: 3492 samples
# Label 3: 451 samples
#
# Plotting first 5 ECG signals from the training set:
# Plotting first 5 ECG signals from the test set:

# %%
# attention cnn
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    A Residual Block as introduced in ResNet.
    """
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.elu = nn.ELU(inplace=True)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm1d(out_channels)
        self.downsample = downsample
        self.se = SELayer(out_channels)  # Squeeze-and-Excitation

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.elu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.se(out)  # Apply SE block

        if self.downsample:
            identity = self.downsample(x)

        out += identity
        out = self.elu(out)

        return out


class SELayer(nn.Module):
    """
    Squeeze-and-Excitation (SE) block.
    """
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.fc1 = nn.Linear(channel, channel // reduction, bias=False)
        self.fc2 = nn.Linear(channel // reduction, channel, bias=False)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        # Squeeze
        b, c, _ = x.size()
        y = F.adaptive_avg_pool1d(x, 1).view(b, c)
        # Excitation
        y = self.fc1(y)
        y = F.relu(y, inplace=True)
        y = self.fc2(y)
        y = self.sigmoid(y).view(b, c, 1)
        # Scale
        return x * y.expand_as(x)


class GlobalAttention(nn.Module):
    """
    Global Attention mechanism that takes into account both ECG and duration features.
    """
    def __init__(self, ecg_feature_size, duration_feature_size, intermediate_size=128):
        super(GlobalAttention, self).__init__()
        self.fc1 = nn.Linear(ecg_feature_size + duration_feature_size, intermediate_size, bias=False)
        self.elu = nn.ELU(inplace=True)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(intermediate_size, ecg_feature_size, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, ecg_features, duration_features):
        """
        Args:
            ecg_features (torch.Tensor): Shape [batch_size, ecg_feature_size]
            duration_features (torch.Tensor): Shape [batch_size, duration_feature_size]
        
        Returns:
            torch.Tensor: Attention weights of shape [batch_size, ecg_feature_size]
        """
        combined = torch.cat((ecg_features, duration_features), dim=-1)  # [batch_size, ecg + duration]
        y = self.fc1(combined)  # [batch_size, intermediate_size]
        y = self.elu(y)
        y = self.dropout(y)
        y = self.fc2(y)  # [batch_size, ecg_feature_size]
        y = self.sigmoid(y)  # [batch_size, ecg_feature_size]
        return y


class AttentionConvFcClassifier(nn.Module):
    def __init__(self, num_classes=3, target_length=32, cycle_num=2, lead_num=1):
        """
        Enhanced ConvFcClassifier with Residual Blocks, SE layers, and Global Attention.

        Args:
            num_classes (int): Number of target classes for classification.
            target_length (int): The desired sequence length after adaptive pooling.
            cycle_num (int): Number of ECG cycles per sample.
        """
        super(AttentionConvFcClassifier, self).__init__()
        
        self.cycle_num = cycle_num
        self.cycle_length = 256  # Assuming fixed length of each cycle
        self.lead_num = lead_num

        # Initial Convolution for ECG Data
        self.initial_conv = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8*cycle_num*lead_num, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm1d(8*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        )
        
        # Residual Layers for ECG Data
        self.layer1 = self._make_layer(8*cycle_num*lead_num, 16*cycle_num*lead_num, blocks=2, stride=2)
        self.layer2 = self._make_layer(16*cycle_num*lead_num, 32*cycle_num*lead_num, blocks=2, stride=2)
        self.layer3 = self._make_layer(32*cycle_num*lead_num, 64*cycle_num*lead_num, blocks=2, stride=2)
        
        # Adaptive Pooling for ECG Data
        self.adaptive_pool = nn.AdaptiveAvgPool1d(target_length)
        
        # Global Context Attention for ECG Data and Duration
        # The attention now takes into account both ECG and duration features
        # ECG features size after adaptive pooling: 64*cycle_num * target_length
        # Duration features size after projection: 64*cycle_num
        self.global_attention = GlobalAttention(
            ecg_feature_size=64*cycle_num*lead_num * target_length,
            duration_feature_size=64*cycle_num*lead_num,
            intermediate_size=128*cycle_num*lead_num
        )
        
        # Projection Layer for Duration Feature
        self.duration_projection = nn.Sequential(
            nn.Linear(cycle_num*lead_num, 64 * cycle_num*lead_num),
            nn.BatchNorm1d(64 * cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5)
        )
        
        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(64*cycle_num * target_length * lead_num + 64*cycle_num*lead_num, 64*cycle_num*lead_num),
            nn.BatchNorm1d(64*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(64*cycle_num*lead_num, 32*cycle_num*lead_num),
            nn.BatchNorm1d(32*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(32*cycle_num*lead_num, num_classes)  # Output layer without activation (logits)
        )

    def _make_layer(self, in_channels, out_channels, blocks, stride=1):
        """
        Creates a layer consisting of Residual Blocks.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            blocks (int): Number of Residual Blocks.
            stride (int): Stride for the first block.

        Returns:
            nn.Sequential: A sequential container of Residual Blocks.
        """
        downsample = None
        if stride != 1 or in_channels != out_channels:
            downsample = nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm1d(out_channels)
            )

        layers = []
        layers.append(ResidualBlock(in_channels, out_channels, stride=stride, downsample=downsample))
        for _ in range(1, blocks):
            layers.append(ResidualBlock(out_channels, out_channels))

        return nn.Sequential(*layers)


    def forward(self, x, modes):
        """
        Forward pass of the ConvFcClassifier.

        Args:
            x (torch.Tensor): Input tensor of shape [batch_size, 1, sequence_length]

        Returns:
            torch.Tensor: Logits tensor of shape [batch_size, num_classes]
        """
        # Split the input into ECG cycles and duration
        # Assuming the last dimension is the sequence length, and duration is a separate feature
        # Modify this part based on the actual input format
        # Here, we assume that the duration is the last value in the sequence
        
        
        duration_idx = self.cycle_num * self.lead_num
        ecg_data = x[:, :, :-duration_idx]  # All cycles data
        duration = x[:, :, -duration_idx:]    # Duration feature, shape: [batch_size, 1]
        duration = duration.squeeze(1)


        # Reshape ECG data to have shape (batch_size, 1, cycles_length * cycle_num)
        # ecg_data = ecg_data.view(ecg_data.size(0), 1, -1)


        # Convolutional layers for ECG data
        ecg_features = self.initial_conv(ecg_data)

        

        ecg_features = self.layer1(ecg_features)
        ecg_features = self.layer2(ecg_features)
        ecg_features = self.layer3(ecg_features)
        ecg_features = self.adaptive_pool(ecg_features)  # Shape: [batch_size, 64*cycle_num, target_length]

        

        # Flatten the ECG feature map
        ecg_flat = ecg_features.view(ecg_features.size(0), -1)  # Shape: [batch_size, 64*cycle_num * target_length]

        # Project duration feature
        duration_proj = self.duration_projection(duration).squeeze(-1)  # Shape: [batch_size, 64*cycle_num]

        # Compute attention weights using both ECG and duration features
        attention_weights = self.global_attention(ecg_flat, duration_proj)  # Shape: [batch_size, 64*cycle_num * target_length]

        

        attention_weights = attention_weights.view(ecg_features.size(0), 64*self.cycle_num*self.lead_num, -1)  # Shape: [batch_size, 64*cycle_num, target_length]
        ecg_features = ecg_features * attention_weights  # Apply attention


        # Flatten after attention
        ecg_flat = ecg_features.view(ecg_features.size(0), -1)  # Shape: [batch_size, 64*cycle_num * target_length]

        # Concatenate ECG features with projected duration
        combined_features = torch.cat((ecg_flat, duration_proj), dim=-1)  # Shape: [batch_size, 64*cycle_num * target_length + 64*cycle_num]

        # Classification head
        out = self.classifier(combined_features)  # Shape: [batch_size, num_classes]

        return out

# %%
# ConvFcClassifier
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    A Residual Block as introduced in ResNet.
    """
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.elu = nn.ELU(inplace=True)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm1d(out_channels)
        self.downsample = downsample
        self.se = SELayer(out_channels)  # Squeeze-and-Excitation

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.elu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.se(out)  # Apply SE block

        if self.downsample:
            identity = self.downsample(x)

        out += identity
        out = self.elu(out)

        return out


class SELayer(nn.Module):
    """
    Squeeze-and-Excitation (SE) block.
    """
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.fc1 = nn.Linear(channel, channel // reduction, bias=False)
        self.fc2 = nn.Linear(channel // reduction, channel, bias=False)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        # Squeeze
        b, c, _ = x.size()
        y = F.adaptive_avg_pool1d(x, 1).view(b, c)
        # Excitation
        y = self.fc1(y)
        y = F.relu(y, inplace=True)
        y = self.fc2(y)
        y = self.sigmoid(y).view(b, c, 1)
        # Scale
        return x * y.expand_as(x)


class ConvFcClassifier(nn.Module):
    def __init__(self, num_classes=3, target_length=32, cycle_num=2, lead_num=1):
        """
        Enhanced ConvFcClassifier with Residual Blocks and SE layers.

        Args:
            num_classes (int): Number of target classes for classification.
            target_length (int): The desired sequence length after adaptive pooling.
            cycle_num (int): Number of ECG cycles per sample.
        """
        super(ConvFcClassifier, self).__init__()
        
        self.cycle_num = cycle_num
        self.cycle_length = 256  # Assuming fixed length of each cycle

        # Initial Convolution for ECG Data
        self.initial_conv = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8*cycle_num*lead_num, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm1d(8*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        )
        
        # Residual Layers for ECG Data
        self.layer1 = self._make_layer(8*cycle_num*lead_num, 16*cycle_num*lead_num, blocks=2, stride=2)
        self.layer2 = self._make_layer(16*cycle_num*lead_num, 32*cycle_num*lead_num, blocks=2, stride=2)
        self.layer3 = self._make_layer(32*cycle_num*lead_num, 64*cycle_num*lead_num, blocks=2, stride=2)
        
        # Adaptive Pooling for ECG Data
        self.adaptive_pool = nn.AdaptiveAvgPool1d(target_length)
        
        # Projection Layer for Duration Feature
        self.duration_projection = nn.Sequential(
            nn.Linear(cycle_num*lead_num, 64 * cycle_num*lead_num),
            nn.BatchNorm1d(64 * cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5)
        )
        
        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(64*cycle_num * target_length*lead_num + 64*cycle_num*lead_num, 64*cycle_num*lead_num),
            nn.BatchNorm1d(64*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(64*cycle_num, 32*cycle_num*lead_num),
            nn.BatchNorm1d(32*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(32*cycle_num*lead_num, num_classes)  # Output layer without activation (logits)
        )

    def _make_layer(self, in_channels, out_channels, blocks, stride=1):
        """
        Creates a layer consisting of Residual Blocks.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            blocks (int): Number of Residual Blocks.
            stride (int): Stride for the first block.

        Returns:
            nn.Sequential: A sequential container of Residual Blocks.
        """
        downsample = None
        if stride != 1 or in_channels != out_channels:
            downsample = nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm1d(out_channels)
            )

        layers = []
        layers.append(ResidualBlock(in_channels, out_channels, stride=stride, downsample=downsample))
        for _ in range(1, blocks):
            layers.append(ResidualBlock(out_channels, out_channels))

        return nn.Sequential(*layers)


    def forward(self, x, modes):
        """
        Forward pass of the ConvFcClassifier.

        Args:
            x (torch.Tensor): Input tensor of shape [batch_size, 1, sequence_length]

        Returns:
            torch.Tensor: Logits tensor of shape [batch_size, num_classes]
        """
        # Split the input into ECG cycles and duration
        # Assuming the last element in the sequence is the duration feature
        ecg_data = x[:, :, :-self.cycle_num]  # All cycles data
        duration = x[:, :, -self.cycle_num:]    # Duration feature, shape: [batch_size, 1]

        # Reshape ECG data to have shape (batch_size, 1, cycles_length * cycle_num)
        # ecg_data = ecg_data.view(ecg_data.size(0), 1, -1)
        duration = duration.squeeze(1)

        # Convolutional layers for ECG data
        ecg_features = self.initial_conv(ecg_data)
        ecg_features = self.layer1(ecg_features)
        ecg_features = self.layer2(ecg_features)
        ecg_features = self.layer3(ecg_features)
        ecg_features = self.adaptive_pool(ecg_features)  # Shape: [batch_size, 64*cycle_num, target_length]

        # Flatten the ECG feature map
        ecg_flat = ecg_features.view(ecg_features.size(0), -1)  # Shape: [batch_size, 64*cycle_num * target_length]

        # Project duration feature
        duration_proj = self.duration_projection(duration).squeeze(-1)  # Shape: [batch_size, 64*cycle_num]

        # Concatenate ECG features with projected duration
        combined_features = torch.cat((ecg_flat, duration_proj), dim=-1)  # Shape: [batch_size, 64*cycle_num * target_length + 64*cycle_num]

        # Classification head
        out = self.classifier(combined_features)  # Shape: [batch_size, num_classes]

        return out

# %%
# LightweightConvFcClassifier
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    A Residual Block as introduced in ResNet.
    """
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.elu = nn.ELU(inplace=True)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm1d(out_channels)
        self.downsample = downsample

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.elu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.downsample:
            identity = self.downsample(x)

        out += identity
        out = self.elu(out)

        return out

class LightweightConvFcClassifier(nn.Module):
    def __init__(self, num_classes=3, target_length=32, cycle_num=2, lead_num=1):
        """
        Enhanced ConvFcClassifier with Residual Blocks.

        Args:
            num_classes (int): Number of target classes for classification.
            target_length (int): The desired sequence length after adaptive pooling.
            cycle_num (int): Number of ECG cycles per sample.
        """
        super(LightweightConvFcClassifier, self).__init__()
        
        self.cycle_num = cycle_num
        self.cycle_length = 256  # Assuming fixed length of each cycle

        # Initial Convolution for ECG Data
        self.initial_conv = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8*cycle_num*lead_num, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm1d(8*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        )
        
        # Residual Layers for ECG Data
        self.layer1 = self._make_layer(8*cycle_num*lead_num, 16*cycle_num*lead_num, blocks=2, stride=2)
        self.layer2 = self._make_layer(16*cycle_num*lead_num, 32*cycle_num*lead_num, blocks=2, stride=2)
        self.layer3 = self._make_layer(32*cycle_num*lead_num, 64*cycle_num*lead_num, blocks=2, stride=2)
        
        # Adaptive Pooling for ECG Data
        self.adaptive_pool = nn.AdaptiveAvgPool1d(target_length)
        
        # Projection Layer for Duration Feature
        self.duration_projection = nn.Sequential(
            nn.Linear(cycle_num*lead_num, 64 * cycle_num*lead_num),
            nn.BatchNorm1d(64 * cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5)
        )
        
        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(64*cycle_num * target_length*lead_num + 64*cycle_num*lead_num, 64*cycle_num*lead_num),
            nn.BatchNorm1d(64*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(64*cycle_num*lead_num, 32*cycle_num*lead_num),
            nn.BatchNorm1d(32*cycle_num*lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(32*cycle_num*lead_num, num_classes)  # Output layer without activation (logits)
        )

    def _make_layer(self, in_channels, out_channels, blocks, stride=1):
        """
        Creates a layer consisting of Residual Blocks.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            blocks (int): Number of Residual Blocks.
            stride (int): Stride for the first block.

        Returns:
            nn.Sequential: A sequential container of Residual Blocks.
        """
        downsample = None
        if stride != 1 or in_channels != out_channels:
            downsample = nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm1d(out_channels)
            )

        layers = []
        layers.append(ResidualBlock(in_channels, out_channels, stride=stride, downsample=downsample))
        for _ in range(1, blocks):
            layers.append(ResidualBlock(out_channels, out_channels))

        return nn.Sequential(*layers)


    def forward(self, x, modes):
        """
        Forward pass of the ConvFcClassifier.

        Args:
            x (torch.Tensor): Input tensor of shape [batch_size, 1, sequence_length]

        Returns:
            torch.Tensor: Logits tensor of shape [batch_size, num_classes]
        """
        # Split the input into ECG cycles and duration
        # Assuming the last element in the sequence is the duration feature
        ecg_data = x[:, :, :-self.cycle_num]  # All cycles data
        duration = x[:, :, -self.cycle_num:]    # Duration feature, shape: [batch_size, 1]

        # Reshape ECG data to have shape (batch_size, 1, cycles_length * cycle_num)
        # ecg_data = ecg_data.view(ecg_data.size(0), 1, -1)
        duration = duration.squeeze(1)

        # Convolutional layers for ECG data
        ecg_features = self.initial_conv(ecg_data)
        ecg_features = self.layer1(ecg_features)
        ecg_features = self.layer2(ecg_features)
        ecg_features = self.layer3(ecg_features)
        ecg_features = self.adaptive_pool(ecg_features)  # Shape: [batch_size, 64*cycle_num, target_length]

        # Flatten the ECG feature map
        ecg_flat = ecg_features.view(ecg_features.size(0), -1)  # Shape: [batch_size, 64*cycle_num * target_length]

        # Project duration feature
        duration_proj = self.duration_projection(duration).squeeze(-1)  # Shape: [batch_size, 64*cycle_num]

        # Concatenate ECG features with projected duration
        combined_features = torch.cat((ecg_flat, duration_proj), dim=-1)  # Shape: [batch_size, 64*cycle_num * target_length + 64*cycle_num]

        # Classification head
        out = self.classifier(combined_features)  # Shape: [batch_size, num_classes]

        return out

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SELayerAMS(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayerAMS, self).__init__()
        self.fc1 = nn.Linear(channel, channel // reduction, bias=False)
        self.fc2 = nn.Linear(channel // reduction, channel, bias=False)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        # x shape: [B, C, T]
        b, c, _ = x.size()
        y = F.adaptive_avg_pool1d(x, 1).view(b, c)
        y = F.relu(self.fc1(y), inplace=True)
        y = self.fc2(y)
        y = self.sigmoid(y).view(b, c, 1)
        return x * y.expand_as(x)

class ResidualBlockAMS(nn.Module):
    """
    Example of a Residual Block with optional SE
    """
    def __init__(self, in_channels, out_channels, stride=1, use_se=True):
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1   = nn.BatchNorm1d(out_channels)
        self.elu   = nn.ELU(inplace=True)

        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2   = nn.BatchNorm1d(out_channels)

        self.downsample = None
        if stride != 1 or in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm1d(out_channels)
            )
        self.use_se = use_se
        if use_se:
            self.se = SELayerAMS(out_channels)

    def forward(self, x):
        identity = x

        out = self.elu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        if self.use_se:
            out = self.se(out)

        if self.downsample:
            identity = self.downsample(x)

        out += identity
        out = self.elu(out)
        return out

class GlobalAttentionAMS(nn.Module):
    """
    Example Global Attention for combining ECG + duration features
    """
    def __init__(self, ecg_dim, dur_dim, hidden_dim=128):
        super().__init__()
        self.fc1 = nn.Linear(ecg_dim + dur_dim, hidden_dim)
        self.elu = nn.ELU(inplace=True)
        self.fc2 = nn.Linear(hidden_dim, ecg_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, ecg_flat, dur_feat):
        # ecg_flat: [B, ecg_dim]
        # dur_feat: [B, dur_dim]
        combined = torch.cat((ecg_flat, dur_feat), dim=-1)
        x = self.elu(self.fc1(combined))
        x = self.fc2(x)
        attn_weights = self.sigmoid(x)  # shape [B, ecg_dim]
        return attn_weights

class SharedAdaptiveConvClassifier(nn.Module):
    """
    A single CNN that can behave as Lightweight, Moderate, or Advanced
    by skipping or including certain blocks or modules.
    """
    def __init__(self, num_classes=5, cycle_num=2, lead_num=1, target_length=32):
        super().__init__()
        self.num_classes    = num_classes
        self.cycle_num      = cycle_num
        self.lead_num       = lead_num
        self.target_length  = target_length

        # ======== SHARED BACKBONE ========
        # For simplicity, let's say we always have these layers
        base_out_ch = 8 * cycle_num * lead_num
        self.initial_conv = nn.Sequential(
            nn.Conv1d(1, base_out_ch, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm1d(base_out_ch),
            nn.ELU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        )

        # Let's define up to 3 residual layers
        # We will allow skipping some in "lightweight" mode
        self.layer1 = ResidualBlockAMS(base_out_ch, 16 * cycle_num * lead_num, stride=2, use_se=True)
        self.layer2 = ResidualBlockAMS(16 * cycle_num * lead_num, 32 * cycle_num * lead_num, stride=2, use_se=True)
        self.layer3 = ResidualBlockAMS(32 * cycle_num * lead_num, 64 * cycle_num * lead_num, stride=2, use_se=True)

        self.adaptive_pool = nn.AdaptiveAvgPool1d(target_length)

        # Duration projection
        self.duration_proj = nn.Sequential(
            nn.Linear(cycle_num * lead_num, 64 * cycle_num * lead_num),
            nn.BatchNorm1d(64 * cycle_num * lead_num),
            nn.ELU(inplace=True),
            nn.Dropout(0.5)
        )

        # ======== OPTIONAL MODULES (e.g., Attention) ========
        # We put them here but only apply in "advanced" mode
        self.global_attention = GlobalAttentionAMS(
            ecg_dim=64*cycle_num*lead_num * target_length,
            dur_dim=64*cycle_num*lead_num,
            hidden_dim=128*cycle_num*lead_num
        )

        # ======== CLASSIFIER HEADS ========
        # Option A: Single big head that can handle both “with or without attention.”
        # Option B: Additional sub-heads for advanced vs. lightweight, etc.
        # For simplicity, we do a single head:
        self.classifier = nn.Sequential(
            nn.Linear(640, 64),
            nn.BatchNorm1d(64),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ELU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(32, num_classes)
        )

    def forward(self, x, modes='moderate'):
        """
        Args:
          x: [batch_size, 1, total_features] 
             last 'self.cycle_num*lead_num' features are durations
          mode: 'lightweight', 'moderate', or 'advanced'
        """

        # 1) Split off the duration features
        duration_idx = self.cycle_num * self.lead_num
        ecg_data = x[:, :, :-duration_idx]   # shape: [B, 1, ecg_points]
        duration = x[:, :, -duration_idx:]   # shape: [B, 1, cycle_num*lead_num]
        duration = duration.squeeze(1)       # shape: [B, cycle_num*lead_num]

        # print("checkpoint 1", ecg_data.shape)

        # 2) Shared backbone
        out = self.initial_conv(ecg_data)

        # print("checkpoint 2", out.shape)

        # Depending on mode, skip or include some layers
        # LIGHTWEIGHT => skip layer3, maybe skip SE inside layers?
        out = self.layer1(out)
        if modes in ('moderate', 'advanced'):
            out = self.layer2(out)
        if modes == 'advanced':
            out = self.layer3(out)

        # print("checkpoint 3", out.shape)

        # 3) Adaptive pooling
        out = self.adaptive_pool(out)  # [B, 16|32|64 * cycle_num*lead_num, target_length]
        ecg_flat = out.view(out.size(0), -1)  # Flatten

        # print("checkpoint 4", ecg_flat.shape)

        # 4) Duration projection
        dur_feat = self.duration_proj(duration)

        # print("checkpoint 5", dur_feat.shape)

        # 5) If advanced, apply global attention
        if modes == 'advanced':
            attn_weights = self.global_attention(ecg_flat, dur_feat)
            # Reshape attention weights to match conv map shape
            # e.g. attn_weights => [B, 64*cycle_num*lead_num * target_length]
            attn_weights = attn_weights.view(out.size(0), out.size(1), out.size(2))
            out = out * attn_weights
            ecg_flat = out.view(out.size(0), -1)

        # print("checkpoint 6", ecg_flat.shape)

        # 6) Concatenate ECG + duration for classification
        combined = torch.cat((ecg_flat, dur_feat), dim=-1)

        # print("checkpoint 7", combined.shape)

        # 7) Classifier
        logits = self.classifier(combined)
        # print("checkpoint 8", logits.shape)
        return logits

# %%
# Define model parameters
num_classes = len(code_to_label)  # Number of target classes
target_length = cycle_num * 8


# Initialize Classifier Models
conv_fc_classifier = ConvFcClassifier(num_classes=num_classes, target_length=target_length, cycle_num=cycle_num, lead_num=lead_num).to(device)
atten_conv_fc_classifier = AttentionConvFcClassifier(num_classes=num_classes, target_length=target_length, cycle_num=cycle_num, lead_num=lead_num).to(device)
light_conv_fc_classifier = LightweightConvFcClassifier(num_classes=num_classes, target_length=cycle_num * 4, cycle_num=cycle_num, lead_num=lead_num).to(device)

# %%
ams_classifier = SharedAdaptiveConvClassifier(num_classes=num_classes, target_length=target_length, cycle_num=cycle_num, lead_num=lead_num).to(device)

# %%
print("Training AMS Classifier...")
ams_classifier, train_losses_ams, val_losses_ams, val_accuracies_ams = train_classifier(
    model=ams_classifier, 
    train_loader=train_loader, 
    val_loader=val_loader, 
    epochs=500, 
    patience=50, 
    lr=0.00005, 
    device=device
)
# Out:
# Training AMS Classifier...
# Epoch 1/500, Train Loss: 1.0982, Val Loss: 0.7366, Val Accuracy: 0.7799
# Validation loss decreased, saving the model...
# Epoch 2/500, Train Loss: 0.7600, Val Loss: 0.5236, Val Accuracy: 0.8446
# Validation loss decreased, saving the model...
# Epoch 3/500, Train Loss: 0.6500, Val Loss: 0.4779, Val Accuracy: 0.8508
# Validation loss decreased, saving the model...
# Epoch 4/500, Train Loss: 0.5952, Val Loss: 0.4575, Val Accuracy: 0.8469
# Validation loss decreased, saving the model...
# Epoch 5/500, Train Loss: 0.5611, Val Loss: 0.4121, Val Accuracy: 0.8633
# Validation loss decreased, saving the model...
# Epoch 6/500, Train Loss: 0.5374, Val Loss: 0.4052, Val Accuracy: 0.8631
# Validation loss decreased, saving the model...
# Epoch 7/500, Train Loss: 0.5169, Val Loss: 0.3959, Val Accuracy: 0.8666
# Validation loss decreased, saving the model...
# Epoch 8/500, Train Loss: 0.5074, Val Loss: 0.3858, Val Accuracy: 0.8713
# Validation loss decreased, saving the model...
# Epoch 9/500, Train Loss: 0.4933, Val Loss: 0.3757, Val Accuracy: 0.8723
# Validation loss decreased, saving the model...
# Epoch 10/500, Train Loss: 0.4858, Val Loss: 0.3730, Val Accuracy: 0.8704
# Validation loss decreased, saving the model...
# Epoch 11/500, Train Loss: 0.4765, Val Loss: 0.3639, Val Accuracy: 0.8753
# Validation loss decreased, saving the model...
# Epoch 12/500, Train Loss: 0.4691, Val Loss: 0.3934, Val Accuracy: 0.8611
# No improvement in validation loss for 1 epoch(s).
# Epoch 13/500, Train Loss: 0.4641, Val Loss: 0.3632, Val Accuracy: 0.8731
# Validation loss decreased, saving the model...
# Epoch 14/500, Train Loss: 0.4578, Val Loss: 0.3525, Val Accuracy: 0.8814
# Validation loss decreased, saving the model...
# Epoch 15/500, Train Loss: 0.4549, Val Loss: 0.3483, Val Accuracy: 0.8787
# Validation loss decreased, saving the model...
# Epoch 16/500, Train Loss: 0.4492, Val Loss: 0.3563, Val Accuracy: 0.8783
# No improvement in validation loss for 1 epoch(s).
# Epoch 17/500, Train Loss: 0.4455, Val Loss: 0.3427, Val Accuracy: 0.8797
# Validation loss decreased, saving the model...
# Epoch 18/500, Train Loss: 0.4397, Val Loss: 0.3384, Val Accuracy: 0.8800
# Validation loss decreased, saving the model...
# Epoch 19/500, Train Loss: 0.4388, Val Loss: 0.3256, Val Accuracy: 0.8880
# Validation loss decreased, saving the model...
# Epoch 20/500, Train Loss: 0.4326, Val Loss: 0.3292, Val Accuracy: 0.8831
# No improvement in validation loss for 1 epoch(s).
# Epoch 21/500, Train Loss: 0.4317, Val Loss: 0.3414, Val Accuracy: 0.8770
# No improvement in validation loss for 2 epoch(s).
# Epoch 22/500, Train Loss: 0.4290, Val Loss: 0.3240, Val Accuracy: 0.8856
# Validation loss decreased, saving the model...
# Epoch 23/500, Train Loss: 0.4258, Val Loss: 0.3175, Val Accuracy: 0.8879
# Validation loss decreased, saving the model...
# Epoch 24/500, Train Loss: 0.4242, Val Loss: 0.3275, Val Accuracy: 0.8833
# No improvement in validation loss for 1 epoch(s).
# Epoch 25/500, Train Loss: 0.4208, Val Loss: 0.3171, Val Accuracy: 0.8907
# Validation loss decreased, saving the model...
# Epoch 26/500, Train Loss: 0.4173, Val Loss: 0.3137, Val Accuracy: 0.8907
# Validation loss decreased, saving the model...
# Epoch 27/500, Train Loss: 0.4150, Val Loss: 0.3218, Val Accuracy: 0.8831
# No improvement in validation loss for 1 epoch(s).
# Epoch 28/500, Train Loss: 0.4144, Val Loss: 0.3184, Val Accuracy: 0.8877
# No improvement in validation loss for 2 epoch(s).
# Epoch 29/500, Train Loss: 0.4119, Val Loss: 0.3323, Val Accuracy: 0.8801
# No improvement in validation loss for 3 epoch(s).
# Epoch 30/500, Train Loss: 0.4093, Val Loss: 0.3128, Val Accuracy: 0.8887
# Validation loss decreased, saving the model...
# Epoch 31/500, Train Loss: 0.4061, Val Loss: 0.3040, Val Accuracy: 0.8933
# Validation loss decreased, saving the model...
# Epoch 32/500, Train Loss: 0.4066, Val Loss: 0.3147, Val Accuracy: 0.8887
# No improvement in validation loss for 1 epoch(s).
# Epoch 33/500, Train Loss: 0.4039, Val Loss: 0.3039, Val Accuracy: 0.8932
# Validation loss decreased, saving the model...
# Epoch 34/500, Train Loss: 0.3998, Val Loss: 0.3076, Val Accuracy: 0.8895
# No improvement in validation loss for 1 epoch(s).
# Epoch 35/500, Train Loss: 0.3966, Val Loss: 0.3173, Val Accuracy: 0.8864
# No improvement in validation loss for 2 epoch(s).
# Epoch 36/500, Train Loss: 0.3993, Val Loss: 0.3032, Val Accuracy: 0.8934
# Validation loss decreased, saving the model...
# Epoch 37/500, Train Loss: 0.3965, Val Loss: 0.3000, Val Accuracy: 0.8959
# Validation loss decreased, saving the model...
# Epoch 38/500, Train Loss: 0.3927, Val Loss: 0.3074, Val Accuracy: 0.8890
# No improvement in validation loss for 1 epoch(s).
# Epoch 39/500, Train Loss: 0.3951, Val Loss: 0.3126, Val Accuracy: 0.8862
# No improvement in validation loss for 2 epoch(s).
# Epoch 40/500, Train Loss: 0.3903, Val Loss: 0.2941, Val Accuracy: 0.8980
# Validation loss decreased, saving the model...
# Epoch 41/500, Train Loss: 0.3912, Val Loss: 0.2929, Val Accuracy: 0.8979
# Validation loss decreased, saving the model...
# Epoch 42/500, Train Loss: 0.3907, Val Loss: 0.3000, Val Accuracy: 0.8937
# No improvement in validation loss for 1 epoch(s).
# Epoch 43/500, Train Loss: 0.3882, Val Loss: 0.2926, Val Accuracy: 0.8948
# Validation loss decreased, saving the model...
# Epoch 44/500, Train Loss: 0.3854, Val Loss: 0.2958, Val Accuracy: 0.8946
# No improvement in validation loss for 1 epoch(s).
# Epoch 45/500, Train Loss: 0.3859, Val Loss: 0.2950, Val Accuracy: 0.8929
# No improvement in validation loss for 2 epoch(s).
# Epoch 46/500, Train Loss: 0.3838, Val Loss: 0.2956, Val Accuracy: 0.8959
# No improvement in validation loss for 3 epoch(s).
# Epoch 47/500, Train Loss: 0.3862, Val Loss: 0.2950, Val Accuracy: 0.8960
# No improvement in validation loss for 4 epoch(s).
# Epoch 48/500, Train Loss: 0.3824, Val Loss: 0.2911, Val Accuracy: 0.9005
# Validation loss decreased, saving the model...
# Epoch 49/500, Train Loss: 0.3838, Val Loss: 0.2932, Val Accuracy: 0.8955
# No improvement in validation loss for 1 epoch(s).
# Epoch 50/500, Train Loss: 0.3813, Val Loss: 0.2893, Val Accuracy: 0.9005
# Validation loss decreased, saving the model...
# Epoch 51/500, Train Loss: 0.3809, Val Loss: 0.3046, Val Accuracy: 0.8875
# No improvement in validation loss for 1 epoch(s).
# Epoch 52/500, Train Loss: 0.3786, Val Loss: 0.2886, Val Accuracy: 0.8971
# Validation loss decreased, saving the model...
# Epoch 53/500, Train Loss: 0.3768, Val Loss: 0.2981, Val Accuracy: 0.8930
# No improvement in validation loss for 1 epoch(s).
# Epoch 54/500, Train Loss: 0.3783, Val Loss: 0.3032, Val Accuracy: 0.8918
# No improvement in validation loss for 2 epoch(s).
# Epoch 55/500, Train Loss: 0.3752, Val Loss: 0.2897, Val Accuracy: 0.8943
# No improvement in validation loss for 3 epoch(s).
# Epoch 56/500, Train Loss: 0.3741, Val Loss: 0.2830, Val Accuracy: 0.9025
# Validation loss decreased, saving the model...
# Epoch 57/500, Train Loss: 0.3747, Val Loss: 0.2812, Val Accuracy: 0.9008
# Validation loss decreased, saving the model...
# Epoch 58/500, Train Loss: 0.3743, Val Loss: 0.2838, Val Accuracy: 0.8972
# No improvement in validation loss for 1 epoch(s).
# Epoch 59/500, Train Loss: 0.3694, Val Loss: 0.2865, Val Accuracy: 0.8970
# No improvement in validation loss for 2 epoch(s).
# Epoch 60/500, Train Loss: 0.3712, Val Loss: 0.2814, Val Accuracy: 0.8992
# No improvement in validation loss for 3 epoch(s).
# Epoch 61/500, Train Loss: 0.3697, Val Loss: 0.2863, Val Accuracy: 0.8992
# No improvement in validation loss for 4 epoch(s).
# Epoch 62/500, Train Loss: 0.3707, Val Loss: 0.2900, Val Accuracy: 0.8948
# No improvement in validation loss for 5 epoch(s).
# Epoch 63/500, Train Loss: 0.3666, Val Loss: 0.2877, Val Accuracy: 0.8963
# No improvement in validation loss for 6 epoch(s).
# Epoch 64/500, Train Loss: 0.3708, Val Loss: 0.2721, Val Accuracy: 0.9037
# Validation loss decreased, saving the model...
# Epoch 65/500, Train Loss: 0.3652, Val Loss: 0.3034, Val Accuracy: 0.8872
# No improvement in validation loss for 1 epoch(s).
# Epoch 66/500, Train Loss: 0.3650, Val Loss: 0.2755, Val Accuracy: 0.9033
# No improvement in validation loss for 2 epoch(s).
# Epoch 67/500, Train Loss: 0.3660, Val Loss: 0.2763, Val Accuracy: 0.9012
# No improvement in validation loss for 3 epoch(s).
# Epoch 68/500, Train Loss: 0.3642, Val Loss: 0.2722, Val Accuracy: 0.9036
# No improvement in validation loss for 4 epoch(s).
# Epoch 69/500, Train Loss: 0.3652, Val Loss: 0.2805, Val Accuracy: 0.8980
# No improvement in validation loss for 5 epoch(s).
# Epoch 70/500, Train Loss: 0.3632, Val Loss: 0.2708, Val Accuracy: 0.9047
# Validation loss decreased, saving the model...
# Epoch 71/500, Train Loss: 0.3617, Val Loss: 0.2683, Val Accuracy: 0.9046
# Validation loss decreased, saving the model...
# Epoch 72/500, Train Loss: 0.3613, Val Loss: 0.2841, Val Accuracy: 0.8961
# No improvement in validation loss for 1 epoch(s).
# Epoch 73/500, Train Loss: 0.3633, Val Loss: 0.2733, Val Accuracy: 0.9036
# No improvement in validation loss for 2 epoch(s).
# Epoch 74/500, Train Loss: 0.3609, Val Loss: 0.2787, Val Accuracy: 0.8996
# No improvement in validation loss for 3 epoch(s).
# Epoch 75/500, Train Loss: 0.3634, Val Loss: 0.2821, Val Accuracy: 0.8967
# No improvement in validation loss for 4 epoch(s).
# Epoch 76/500, Train Loss: 0.3597, Val Loss: 0.2660, Val Accuracy: 0.9039
# Validation loss decreased, saving the model...
# Epoch 77/500, Train Loss: 0.3607, Val Loss: 0.2691, Val Accuracy: 0.9044
# No improvement in validation loss for 1 epoch(s).
# Epoch 78/500, Train Loss: 0.3552, Val Loss: 0.2826, Val Accuracy: 0.8991
# No improvement in validation loss for 2 epoch(s).
# Epoch 79/500, Train Loss: 0.3577, Val Loss: 0.2675, Val Accuracy: 0.9036
# No improvement in validation loss for 3 epoch(s).
# Epoch 80/500, Train Loss: 0.3552, Val Loss: 0.2681, Val Accuracy: 0.9069
# No improvement in validation loss for 4 epoch(s).
# Epoch 81/500, Train Loss: 0.3563, Val Loss: 0.2657, Val Accuracy: 0.9057
# Validation loss decreased, saving the model...
# Epoch 82/500, Train Loss: 0.3568, Val Loss: 0.2772, Val Accuracy: 0.8999
# No improvement in validation loss for 1 epoch(s).
# Epoch 83/500, Train Loss: 0.3564, Val Loss: 0.2710, Val Accuracy: 0.9053
# No improvement in validation loss for 2 epoch(s).
# Epoch 84/500, Train Loss: 0.3532, Val Loss: 0.2683, Val Accuracy: 0.9034
# No improvement in validation loss for 3 epoch(s).
# Epoch 85/500, Train Loss: 0.3535, Val Loss: 0.2683, Val Accuracy: 0.9057
# No improvement in validation loss for 4 epoch(s).
# Epoch 86/500, Train Loss: 0.3532, Val Loss: 0.2661, Val Accuracy: 0.9055
# No improvement in validation loss for 5 epoch(s).
# Epoch 87/500, Train Loss: 0.3505, Val Loss: 0.2643, Val Accuracy: 0.9088
# Validation loss decreased, saving the model...
# Epoch 88/500, Train Loss: 0.3553, Val Loss: 0.2626, Val Accuracy: 0.9059
# Validation loss decreased, saving the model...
# Epoch 89/500, Train Loss: 0.3522, Val Loss: 0.2753, Val Accuracy: 0.8979
# No improvement in validation loss for 1 epoch(s).
# Epoch 90/500, Train Loss: 0.3493, Val Loss: 0.2691, Val Accuracy: 0.9021
# No improvement in validation loss for 2 epoch(s).
# Epoch 91/500, Train Loss: 0.3513, Val Loss: 0.2696, Val Accuracy: 0.9045
# No improvement in validation loss for 3 epoch(s).
# Epoch 92/500, Train Loss: 0.3494, Val Loss: 0.2672, Val Accuracy: 0.9046
# No improvement in validation loss for 4 epoch(s).
# Epoch 93/500, Train Loss: 0.3497, Val Loss: 0.2846, Val Accuracy: 0.8953
# No improvement in validation loss for 5 epoch(s).
# Epoch 94/500, Train Loss: 0.3482, Val Loss: 0.2780, Val Accuracy: 0.9021
# No improvement in validation loss for 6 epoch(s).
# Epoch 95/500, Train Loss: 0.3453, Val Loss: 0.2590, Val Accuracy: 0.9078
# Validation loss decreased, saving the model...
# Epoch 96/500, Train Loss: 0.3493, Val Loss: 0.2578, Val Accuracy: 0.9096
# Validation loss decreased, saving the model...
# Epoch 97/500, Train Loss: 0.3490, Val Loss: 0.2600, Val Accuracy: 0.9068
# No improvement in validation loss for 1 epoch(s).
# Epoch 98/500, Train Loss: 0.3455, Val Loss: 0.2631, Val Accuracy: 0.9073
# No improvement in validation loss for 2 epoch(s).
# Epoch 99/500, Train Loss: 0.3484, Val Loss: 0.2596, Val Accuracy: 0.9082
# No improvement in validation loss for 3 epoch(s).
# Epoch 100/500, Train Loss: 0.3447, Val Loss: 0.2701, Val Accuracy: 0.9043
# No improvement in validation loss for 4 epoch(s).
# Epoch 101/500, Train Loss: 0.3456, Val Loss: 0.2644, Val Accuracy: 0.9052
# No improvement in validation loss for 5 epoch(s).
# Epoch 102/500, Train Loss: 0.3449, Val Loss: 0.2614, Val Accuracy: 0.9071
# No improvement in validation loss for 6 epoch(s).
# Epoch 103/500, Train Loss: 0.3438, Val Loss: 0.2639, Val Accuracy: 0.9069
# No improvement in validation loss for 7 epoch(s).
# Epoch 104/500, Train Loss: 0.3461, Val Loss: 0.2845, Val Accuracy: 0.8930
# No improvement in validation loss for 8 epoch(s).
# Epoch 105/500, Train Loss: 0.3419, Val Loss: 0.2609, Val Accuracy: 0.9087
# No improvement in validation loss for 9 epoch(s).
# Epoch 106/500, Train Loss: 0.3443, Val Loss: 0.2679, Val Accuracy: 0.9036
# No improvement in validation loss for 10 epoch(s).
# Epoch 107/500, Train Loss: 0.3427, Val Loss: 0.2637, Val Accuracy: 0.9083
# No improvement in validation loss for 11 epoch(s).
# Epoch 108/500, Train Loss: 0.3439, Val Loss: 0.2533, Val Accuracy: 0.9093
# Validation loss decreased, saving the model...
# Epoch 109/500, Train Loss: 0.3425, Val Loss: 0.2562, Val Accuracy: 0.9087
# No improvement in validation loss for 1 epoch(s).
# Epoch 110/500, Train Loss: 0.3427, Val Loss: 0.2530, Val Accuracy: 0.9101
# Validation loss decreased, saving the model...
# Epoch 111/500, Train Loss: 0.3426, Val Loss: 0.2604, Val Accuracy: 0.9064
# No improvement in validation loss for 1 epoch(s).
# Epoch 112/500, Train Loss: 0.3422, Val Loss: 0.2574, Val Accuracy: 0.9102
# No improvement in validation loss for 2 epoch(s).
# Epoch 113/500, Train Loss: 0.3419, Val Loss: 0.2601, Val Accuracy: 0.9064
# No improvement in validation loss for 3 epoch(s).
# Epoch 114/500, Train Loss: 0.3379, Val Loss: 0.2560, Val Accuracy: 0.9102
# No improvement in validation loss for 4 epoch(s).
# Epoch 115/500, Train Loss: 0.3419, Val Loss: 0.2503, Val Accuracy: 0.9132
# Validation loss decreased, saving the model...
# Epoch 116/500, Train Loss: 0.3405, Val Loss: 0.2505, Val Accuracy: 0.9126
# No improvement in validation loss for 1 epoch(s).
# Epoch 117/500, Train Loss: 0.3389, Val Loss: 0.2481, Val Accuracy: 0.9133
# Validation loss decreased, saving the model...
# Epoch 118/500, Train Loss: 0.3380, Val Loss: 0.2537, Val Accuracy: 0.9097
# No improvement in validation loss for 1 epoch(s).
# Epoch 119/500, Train Loss: 0.3397, Val Loss: 0.2552, Val Accuracy: 0.9093
# No improvement in validation loss for 2 epoch(s).
# Epoch 120/500, Train Loss: 0.3375, Val Loss: 0.2503, Val Accuracy: 0.9114
# No improvement in validation loss for 3 epoch(s).
# Epoch 121/500, Train Loss: 0.3381, Val Loss: 0.2511, Val Accuracy: 0.9112
# No improvement in validation loss for 4 epoch(s).
# Epoch 122/500, Train Loss: 0.3386, Val Loss: 0.2526, Val Accuracy: 0.9099
# No improvement in validation loss for 5 epoch(s).
# Epoch 123/500, Train Loss: 0.3363, Val Loss: 0.2556, Val Accuracy: 0.9085
# No improvement in validation loss for 6 epoch(s).
# Epoch 124/500, Train Loss: 0.3371, Val Loss: 0.2539, Val Accuracy: 0.9090
# No improvement in validation loss for 7 epoch(s).
# Epoch 125/500, Train Loss: 0.3365, Val Loss: 0.2622, Val Accuracy: 0.9080
# No improvement in validation loss for 8 epoch(s).
# Epoch 126/500, Train Loss: 0.3351, Val Loss: 0.2580, Val Accuracy: 0.9075
# No improvement in validation loss for 9 epoch(s).
# Epoch 127/500, Train Loss: 0.3339, Val Loss: 0.2552, Val Accuracy: 0.9084
# No improvement in validation loss for 10 epoch(s).
# Epoch 128/500, Train Loss: 0.3353, Val Loss: 0.2467, Val Accuracy: 0.9128
# Validation loss decreased, saving the model...
# Epoch 129/500, Train Loss: 0.3357, Val Loss: 0.2559, Val Accuracy: 0.9079
# No improvement in validation loss for 1 epoch(s).
# Epoch 130/500, Train Loss: 0.3331, Val Loss: 0.2832, Val Accuracy: 0.8969
# No improvement in validation loss for 2 epoch(s).
# Epoch 131/500, Train Loss: 0.3319, Val Loss: 0.2616, Val Accuracy: 0.9064
# No improvement in validation loss for 3 epoch(s).
# Epoch 132/500, Train Loss: 0.3335, Val Loss: 0.2550, Val Accuracy: 0.9103
# No improvement in validation loss for 4 epoch(s).
# Epoch 133/500, Train Loss: 0.3329, Val Loss: 0.2695, Val Accuracy: 0.9016
# No improvement in validation loss for 5 epoch(s).
# Epoch 134/500, Train Loss: 0.3304, Val Loss: 0.2489, Val Accuracy: 0.9121
# No improvement in validation loss for 6 epoch(s).
# Epoch 135/500, Train Loss: 0.3319, Val Loss: 0.2519, Val Accuracy: 0.9106
# No improvement in validation loss for 7 epoch(s).
# Epoch 136/500, Train Loss: 0.3325, Val Loss: 0.2445, Val Accuracy: 0.9147
# Validation loss decreased, saving the model...
# Epoch 137/500, Train Loss: 0.3348, Val Loss: 0.2468, Val Accuracy: 0.9120
# No improvement in validation loss for 1 epoch(s).
# Epoch 138/500, Train Loss: 0.3324, Val Loss: 0.2486, Val Accuracy: 0.9108
# No improvement in validation loss for 2 epoch(s).
# Epoch 139/500, Train Loss: 0.3312, Val Loss: 0.2636, Val Accuracy: 0.9087
# No improvement in validation loss for 3 epoch(s).
# Epoch 140/500, Train Loss: 0.3281, Val Loss: 0.2485, Val Accuracy: 0.9112
# No improvement in validation loss for 4 epoch(s).
# Epoch 141/500, Train Loss: 0.3320, Val Loss: 0.2433, Val Accuracy: 0.9128
# Validation loss decreased, saving the model...
# Epoch 142/500, Train Loss: 0.3307, Val Loss: 0.2536, Val Accuracy: 0.9090
# No improvement in validation loss for 1 epoch(s).
# Epoch 143/500, Train Loss: 0.3289, Val Loss: 0.2474, Val Accuracy: 0.9101
# No improvement in validation loss for 2 epoch(s).
# Epoch 144/500, Train Loss: 0.3289, Val Loss: 0.2464, Val Accuracy: 0.9127
# No improvement in validation loss for 3 epoch(s).
# Epoch 145/500, Train Loss: 0.3311, Val Loss: 0.2617, Val Accuracy: 0.9070
# No improvement in validation loss for 4 epoch(s).
# Epoch 146/500, Train Loss: 0.3323, Val Loss: 0.2536, Val Accuracy: 0.9101
# No improvement in validation loss for 5 epoch(s).
# Epoch 147/500, Train Loss: 0.3288, Val Loss: 0.2460, Val Accuracy: 0.9114
# No improvement in validation loss for 6 epoch(s).
# Epoch 148/500, Train Loss: 0.3296, Val Loss: 0.2462, Val Accuracy: 0.9127
# No improvement in validation loss for 7 epoch(s).
# Epoch 149/500, Train Loss: 0.3298, Val Loss: 0.2493, Val Accuracy: 0.9111
# No improvement in validation loss for 8 epoch(s).
# Epoch 150/500, Train Loss: 0.3255, Val Loss: 0.2527, Val Accuracy: 0.9107
# No improvement in validation loss for 9 epoch(s).
# Epoch 151/500, Train Loss: 0.3269, Val Loss: 0.2512, Val Accuracy: 0.9091
# No improvement in validation loss for 10 epoch(s).
# Epoch 152/500, Train Loss: 0.3253, Val Loss: 0.2643, Val Accuracy: 0.9039
# No improvement in validation loss for 11 epoch(s).
# Epoch 153/500, Train Loss: 0.3243, Val Loss: 0.2408, Val Accuracy: 0.9154
# Validation loss decreased, saving the model...
# Epoch 154/500, Train Loss: 0.3290, Val Loss: 0.2409, Val Accuracy: 0.9154
# No improvement in validation loss for 1 epoch(s).
# Epoch 155/500, Train Loss: 0.3276, Val Loss: 0.2484, Val Accuracy: 0.9129
# No improvement in validation loss for 2 epoch(s).
# Epoch 156/500, Train Loss: 0.3248, Val Loss: 0.2424, Val Accuracy: 0.9136
# No improvement in validation loss for 3 epoch(s).
# Epoch 157/500, Train Loss: 0.3254, Val Loss: 0.2495, Val Accuracy: 0.9094
# No improvement in validation loss for 4 epoch(s).
# Epoch 158/500, Train Loss: 0.3305, Val Loss: 0.2431, Val Accuracy: 0.9138
# No improvement in validation loss for 5 epoch(s).
# Epoch 159/500, Train Loss: 0.3286, Val Loss: 0.2471, Val Accuracy: 0.9113
# No improvement in validation loss for 6 epoch(s).
# Epoch 160/500, Train Loss: 0.3253, Val Loss: 0.2659, Val Accuracy: 0.9009
# No improvement in validation loss for 7 epoch(s).
# Epoch 161/500, Train Loss: 0.3247, Val Loss: 0.2512, Val Accuracy: 0.9100
# No improvement in validation loss for 8 epoch(s).
# Epoch 162/500, Train Loss: 0.3259, Val Loss: 0.2470, Val Accuracy: 0.9116
# No improvement in validation loss for 9 epoch(s).
# Epoch 163/500, Train Loss: 0.3233, Val Loss: 0.2473, Val Accuracy: 0.9095
# No improvement in validation loss for 10 epoch(s).
# Epoch 164/500, Train Loss: 0.3255, Val Loss: 0.2536, Val Accuracy: 0.9106
# No improvement in validation loss for 11 epoch(s).
# Epoch 165/500, Train Loss: 0.3240, Val Loss: 0.2501, Val Accuracy: 0.9100
# No improvement in validation loss for 12 epoch(s).
# Epoch 166/500, Train Loss: 0.3242, Val Loss: 0.2592, Val Accuracy: 0.9083
# No improvement in validation loss for 13 epoch(s).
# Epoch 167/500, Train Loss: 0.3218, Val Loss: 0.2594, Val Accuracy: 0.9047
# No improvement in validation loss for 14 epoch(s).
# Epoch 168/500, Train Loss: 0.3232, Val Loss: 0.2418, Val Accuracy: 0.9162
# No improvement in validation loss for 15 epoch(s).
# Epoch 169/500, Train Loss: 0.3221, Val Loss: 0.2599, Val Accuracy: 0.9037
# No improvement in validation loss for 16 epoch(s).
# Epoch 170/500, Train Loss: 0.3243, Val Loss: 0.2418, Val Accuracy: 0.9138
# No improvement in validation loss for 17 epoch(s).
# Epoch 171/500, Train Loss: 0.3210, Val Loss: 0.2431, Val Accuracy: 0.9118
# No improvement in validation loss for 18 epoch(s).
# Epoch 172/500, Train Loss: 0.3232, Val Loss: 0.2458, Val Accuracy: 0.9100
# No improvement in validation loss for 19 epoch(s).
# Epoch 173/500, Train Loss: 0.3213, Val Loss: 0.2437, Val Accuracy: 0.9112
# No improvement in validation loss for 20 epoch(s).
# Epoch 174/500, Train Loss: 0.3232, Val Loss: 0.2362, Val Accuracy: 0.9173
# Validation loss decreased, saving the model...
# Epoch 175/500, Train Loss: 0.3207, Val Loss: 0.2589, Val Accuracy: 0.9063
# No improvement in validation loss for 1 epoch(s).
# Epoch 176/500, Train Loss: 0.3236, Val Loss: 0.2397, Val Accuracy: 0.9139
# No improvement in validation loss for 2 epoch(s).
# Epoch 177/500, Train Loss: 0.3207, Val Loss: 0.2359, Val Accuracy: 0.9160
# Validation loss decreased, saving the model...
# Epoch 178/500, Train Loss: 0.3221, Val Loss: 0.2329, Val Accuracy: 0.9174
# Validation loss decreased, saving the model...
# Epoch 179/500, Train Loss: 0.3223, Val Loss: 0.2552, Val Accuracy: 0.9096
# No improvement in validation loss for 1 epoch(s).
# Epoch 180/500, Train Loss: 0.3209, Val Loss: 0.2451, Val Accuracy: 0.9105
# No improvement in validation loss for 2 epoch(s).
# Epoch 181/500, Train Loss: 0.3230, Val Loss: 0.2456, Val Accuracy: 0.9120
# No improvement in validation loss for 3 epoch(s).
# Epoch 182/500, Train Loss: 0.3187, Val Loss: 0.2413, Val Accuracy: 0.9125
# No improvement in validation loss for 4 epoch(s).
# Epoch 183/500, Train Loss: 0.3190, Val Loss: 0.2705, Val Accuracy: 0.9019
# No improvement in validation loss for 5 epoch(s).
# Epoch 184/500, Train Loss: 0.3200, Val Loss: 0.2551, Val Accuracy: 0.9067
# No improvement in validation loss for 6 epoch(s).
# Epoch 185/500, Train Loss: 0.3205, Val Loss: 0.2382, Val Accuracy: 0.9154
# No improvement in validation loss for 7 epoch(s).
# Epoch 186/500, Train Loss: 0.3194, Val Loss: 0.2395, Val Accuracy: 0.9145
# No improvement in validation loss for 8 epoch(s).
# Epoch 187/500, Train Loss: 0.3198, Val Loss: 0.2384, Val Accuracy: 0.9162
# No improvement in validation loss for 9 epoch(s).
# Epoch 188/500, Train Loss: 0.3174, Val Loss: 0.2352, Val Accuracy: 0.9161
# No improvement in validation loss for 10 epoch(s).
# Epoch 189/500, Train Loss: 0.3178, Val Loss: 0.2392, Val Accuracy: 0.9137
# No improvement in validation loss for 11 epoch(s).
# Epoch 190/500, Train Loss: 0.3183, Val Loss: 0.2350, Val Accuracy: 0.9160
# No improvement in validation loss for 12 epoch(s).
# Epoch 191/500, Train Loss: 0.3183, Val Loss: 0.2392, Val Accuracy: 0.9157
# No improvement in validation loss for 13 epoch(s).
# Epoch 192/500, Train Loss: 0.3145, Val Loss: 0.2348, Val Accuracy: 0.9167
# No improvement in validation loss for 14 epoch(s).
# Epoch 193/500, Train Loss: 0.3190, Val Loss: 0.2497, Val Accuracy: 0.9073
# No improvement in validation loss for 15 epoch(s).
# Epoch 194/500, Train Loss: 0.3181, Val Loss: 0.2342, Val Accuracy: 0.9175
# No improvement in validation loss for 16 epoch(s).
# Epoch 195/500, Train Loss: 0.3155, Val Loss: 0.2375, Val Accuracy: 0.9170
# No improvement in validation loss for 17 epoch(s).
# Epoch 196/500, Train Loss: 0.3164, Val Loss: 0.2732, Val Accuracy: 0.9016
# No improvement in validation loss for 18 epoch(s).
# Epoch 197/500, Train Loss: 0.3159, Val Loss: 0.2342, Val Accuracy: 0.9156
# No improvement in validation loss for 19 epoch(s).
# Epoch 198/500, Train Loss: 0.3157, Val Loss: 0.2506, Val Accuracy: 0.9076
# No improvement in validation loss for 20 epoch(s).
# Epoch 199/500, Train Loss: 0.3196, Val Loss: 0.2368, Val Accuracy: 0.9156
# No improvement in validation loss for 21 epoch(s).
# Epoch 200/500, Train Loss: 0.3186, Val Loss: 0.2361, Val Accuracy: 0.9147
# No improvement in validation loss for 22 epoch(s).
# Epoch 201/500, Train Loss: 0.3143, Val Loss: 0.2352, Val Accuracy: 0.9159
# No improvement in validation loss for 23 epoch(s).
# Epoch 202/500, Train Loss: 0.3137, Val Loss: 0.2340, Val Accuracy: 0.9153
# No improvement in validation loss for 24 epoch(s).
# Epoch 203/500, Train Loss: 0.3133, Val Loss: 0.2427, Val Accuracy: 0.9116
# No improvement in validation loss for 25 epoch(s).
# Epoch 204/500, Train Loss: 0.3171, Val Loss: 0.2399, Val Accuracy: 0.9161
# No improvement in validation loss for 26 epoch(s).
# Epoch 205/500, Train Loss: 0.3161, Val Loss: 0.2482, Val Accuracy: 0.9090
# No improvement in validation loss for 27 epoch(s).
# Epoch 206/500, Train Loss: 0.3138, Val Loss: 0.2439, Val Accuracy: 0.9121
# No improvement in validation loss for 28 epoch(s).
# Epoch 207/500, Train Loss: 0.3131, Val Loss: 0.2332, Val Accuracy: 0.9194
# No improvement in validation loss for 29 epoch(s).
# Epoch 208/500, Train Loss: 0.3128, Val Loss: 0.2553, Val Accuracy: 0.9058
# No improvement in validation loss for 30 epoch(s).
# Epoch 209/500, Train Loss: 0.3150, Val Loss: 0.2349, Val Accuracy: 0.9161
# No improvement in validation loss for 31 epoch(s).
# Epoch 210/500, Train Loss: 0.3144, Val Loss: 0.2356, Val Accuracy: 0.9146
# No improvement in validation loss for 32 epoch(s).
# Epoch 211/500, Train Loss: 0.3117, Val Loss: 0.2351, Val Accuracy: 0.9178
# No improvement in validation loss for 33 epoch(s).
# Epoch 212/500, Train Loss: 0.3122, Val Loss: 0.2524, Val Accuracy: 0.9096
# No improvement in validation loss for 34 epoch(s).
# Epoch 213/500, Train Loss: 0.3137, Val Loss: 0.2346, Val Accuracy: 0.9161
# No improvement in validation loss for 35 epoch(s).
# Epoch 214/500, Train Loss: 0.3136, Val Loss: 0.2517, Val Accuracy: 0.9110
# No improvement in validation loss for 36 epoch(s).
# Epoch 215/500, Train Loss: 0.3107, Val Loss: 0.2416, Val Accuracy: 0.9143
# No improvement in validation loss for 37 epoch(s).
# Epoch 216/500, Train Loss: 0.3128, Val Loss: 0.2492, Val Accuracy: 0.9097
# No improvement in validation loss for 38 epoch(s).
# Epoch 217/500, Train Loss: 0.3141, Val Loss: 0.2639, Val Accuracy: 0.9025
# No improvement in validation loss for 39 epoch(s).
# Epoch 218/500, Train Loss: 0.3112, Val Loss: 0.2517, Val Accuracy: 0.9082
# No improvement in validation loss for 40 epoch(s).
# Epoch 219/500, Train Loss: 0.3143, Val Loss: 0.2339, Val Accuracy: 0.9161
# No improvement in validation loss for 41 epoch(s).
# Epoch 220/500, Train Loss: 0.3116, Val Loss: 0.2297, Val Accuracy: 0.9181
# Validation loss decreased, saving the model...
# Epoch 221/500, Train Loss: 0.3125, Val Loss: 0.2306, Val Accuracy: 0.9194
# No improvement in validation loss for 1 epoch(s).
# Epoch 222/500, Train Loss: 0.3103, Val Loss: 0.2377, Val Accuracy: 0.9161
# No improvement in validation loss for 2 epoch(s).
# Epoch 223/500, Train Loss: 0.3090, Val Loss: 0.2409, Val Accuracy: 0.9133
# No improvement in validation loss for 3 epoch(s).
# Epoch 224/500, Train Loss: 0.3132, Val Loss: 0.2314, Val Accuracy: 0.9180
# No improvement in validation loss for 4 epoch(s).
# Epoch 225/500, Train Loss: 0.3103, Val Loss: 0.2436, Val Accuracy: 0.9126
# No improvement in validation loss for 5 epoch(s).
# Epoch 226/500, Train Loss: 0.3097, Val Loss: 0.2327, Val Accuracy: 0.9159
# No improvement in validation loss for 6 epoch(s).
# Epoch 227/500, Train Loss: 0.3125, Val Loss: 0.2429, Val Accuracy: 0.9114
# No improvement in validation loss for 7 epoch(s).
# Epoch 228/500, Train Loss: 0.3082, Val Loss: 0.2326, Val Accuracy: 0.9162
# No improvement in validation loss for 8 epoch(s).
# Epoch 229/500, Train Loss: 0.3119, Val Loss: 0.2371, Val Accuracy: 0.9149
# No improvement in validation loss for 9 epoch(s).
# Epoch 230/500, Train Loss: 0.3083, Val Loss: 0.2408, Val Accuracy: 0.9146
# No improvement in validation loss for 10 epoch(s).
# Epoch 231/500, Train Loss: 0.3083, Val Loss: 0.2522, Val Accuracy: 0.9086
# No improvement in validation loss for 11 epoch(s).
# Epoch 232/500, Train Loss: 0.3077, Val Loss: 0.2366, Val Accuracy: 0.9138
# No improvement in validation loss for 12 epoch(s).
# Epoch 233/500, Train Loss: 0.3082, Val Loss: 0.2461, Val Accuracy: 0.9096
# No improvement in validation loss for 13 epoch(s).
# Epoch 234/500, Train Loss: 0.3079, Val Loss: 0.2366, Val Accuracy: 0.9142
# No improvement in validation loss for 14 epoch(s).
# Epoch 235/500, Train Loss: 0.3125, Val Loss: 0.2343, Val Accuracy: 0.9163
# No improvement in validation loss for 15 epoch(s).
# Epoch 236/500, Train Loss: 0.3103, Val Loss: 0.2623, Val Accuracy: 0.9080
# No improvement in validation loss for 16 epoch(s).
# Epoch 237/500, Train Loss: 0.3089, Val Loss: 0.2309, Val Accuracy: 0.9169
# No improvement in validation loss for 17 epoch(s).
# Epoch 238/500, Train Loss: 0.3092, Val Loss: 0.2423, Val Accuracy: 0.9144
# No improvement in validation loss for 18 epoch(s).
# Epoch 239/500, Train Loss: 0.3087, Val Loss: 0.2383, Val Accuracy: 0.9134
# No improvement in validation loss for 19 epoch(s).
# Epoch 240/500, Train Loss: 0.3114, Val Loss: 0.2387, Val Accuracy: 0.9120
# No improvement in validation loss for 20 epoch(s).
# Epoch 241/500, Train Loss: 0.3063, Val Loss: 0.2385, Val Accuracy: 0.9118
# No improvement in validation loss for 21 epoch(s).
# Epoch 242/500, Train Loss: 0.3060, Val Loss: 0.2338, Val Accuracy: 0.9162
# No improvement in validation loss for 22 epoch(s).
# Epoch 243/500, Train Loss: 0.3050, Val Loss: 0.2285, Val Accuracy: 0.9185
# Validation loss decreased, saving the model...
# Epoch 244/500, Train Loss: 0.3094, Val Loss: 0.2256, Val Accuracy: 0.9210
# Validation loss decreased, saving the model...
# Epoch 245/500, Train Loss: 0.3053, Val Loss: 0.2419, Val Accuracy: 0.9116
# No improvement in validation loss for 1 epoch(s).
# Epoch 246/500, Train Loss: 0.3072, Val Loss: 0.2381, Val Accuracy: 0.9149
# No improvement in validation loss for 2 epoch(s).
# Epoch 247/500, Train Loss: 0.3055, Val Loss: 0.2283, Val Accuracy: 0.9193
# No improvement in validation loss for 3 epoch(s).
# Epoch 248/500, Train Loss: 0.3075, Val Loss: 0.2364, Val Accuracy: 0.9138
# No improvement in validation loss for 4 epoch(s).
# Epoch 249/500, Train Loss: 0.3075, Val Loss: 0.2369, Val Accuracy: 0.9142
# No improvement in validation loss for 5 epoch(s).
# Epoch 250/500, Train Loss: 0.3071, Val Loss: 0.2296, Val Accuracy: 0.9179
# No improvement in validation loss for 6 epoch(s).
# Epoch 251/500, Train Loss: 0.3074, Val Loss: 0.2358, Val Accuracy: 0.9139
# No improvement in validation loss for 7 epoch(s).
# Epoch 252/500, Train Loss: 0.3070, Val Loss: 0.2355, Val Accuracy: 0.9126
# No improvement in validation loss for 8 epoch(s).
# Epoch 253/500, Train Loss: 0.3056, Val Loss: 0.2305, Val Accuracy: 0.9174
# No improvement in validation loss for 9 epoch(s).
# Epoch 254/500, Train Loss: 0.3040, Val Loss: 0.2282, Val Accuracy: 0.9187
# No improvement in validation loss for 10 epoch(s).
# Epoch 255/500, Train Loss: 0.3064, Val Loss: 0.2298, Val Accuracy: 0.9165
# No improvement in validation loss for 11 epoch(s).
# Epoch 256/500, Train Loss: 0.3063, Val Loss: 0.2281, Val Accuracy: 0.9193
# No improvement in validation loss for 12 epoch(s).
# Epoch 257/500, Train Loss: 0.3033, Val Loss: 0.2234, Val Accuracy: 0.9209
# Validation loss decreased, saving the model...
# Epoch 258/500, Train Loss: 0.3045, Val Loss: 0.2359, Val Accuracy: 0.9148
# No improvement in validation loss for 1 epoch(s).
# Epoch 259/500, Train Loss: 0.3023, Val Loss: 0.2366, Val Accuracy: 0.9164
# No improvement in validation loss for 2 epoch(s).
# Epoch 260/500, Train Loss: 0.3026, Val Loss: 0.2275, Val Accuracy: 0.9186
# No improvement in validation loss for 3 epoch(s).
# Epoch 261/500, Train Loss: 0.3051, Val Loss: 0.2267, Val Accuracy: 0.9191
# No improvement in validation loss for 4 epoch(s).
# Epoch 262/500, Train Loss: 0.3036, Val Loss: 0.2354, Val Accuracy: 0.9190
# No improvement in validation loss for 5 epoch(s).
# Epoch 263/500, Train Loss: 0.3035, Val Loss: 0.2408, Val Accuracy: 0.9116
# No improvement in validation loss for 6 epoch(s).
# Epoch 264/500, Train Loss: 0.3027, Val Loss: 0.2295, Val Accuracy: 0.9168
# No improvement in validation loss for 7 epoch(s).
# Epoch 265/500, Train Loss: 0.3046, Val Loss: 0.2465, Val Accuracy: 0.9098
# No improvement in validation loss for 8 epoch(s).
# Epoch 266/500, Train Loss: 0.3042, Val Loss: 0.2263, Val Accuracy: 0.9212
# No improvement in validation loss for 9 epoch(s).
# Epoch 267/500, Train Loss: 0.3042, Val Loss: 0.2421, Val Accuracy: 0.9134
# No improvement in validation loss for 10 epoch(s).
# Epoch 268/500, Train Loss: 0.3043, Val Loss: 0.2332, Val Accuracy: 0.9144
# No improvement in validation loss for 11 epoch(s).
# Epoch 269/500, Train Loss: 0.3038, Val Loss: 0.2260, Val Accuracy: 0.9200
# No improvement in validation loss for 12 epoch(s).
# Epoch 270/500, Train Loss: 0.3021, Val Loss: 0.2359, Val Accuracy: 0.9146
# No improvement in validation loss for 13 epoch(s).
# Epoch 271/500, Train Loss: 0.3047, Val Loss: 0.2492, Val Accuracy: 0.9112
# No improvement in validation loss for 14 epoch(s).
# Epoch 272/500, Train Loss: 0.3038, Val Loss: 0.2288, Val Accuracy: 0.9185
# No improvement in validation loss for 15 epoch(s).
# Epoch 273/500, Train Loss: 0.3027, Val Loss: 0.2411, Val Accuracy: 0.9138
# No improvement in validation loss for 16 epoch(s).
# Epoch 274/500, Train Loss: 0.3021, Val Loss: 0.2265, Val Accuracy: 0.9189
# No improvement in validation loss for 17 epoch(s).
# Epoch 275/500, Train Loss: 0.2986, Val Loss: 0.2260, Val Accuracy: 0.9184
# No improvement in validation loss for 18 epoch(s).
# Epoch 276/500, Train Loss: 0.3017, Val Loss: 0.2440, Val Accuracy: 0.9121
# No improvement in validation loss for 19 epoch(s).
# Epoch 277/500, Train Loss: 0.3024, Val Loss: 0.2395, Val Accuracy: 0.9133
# No improvement in validation loss for 20 epoch(s).
# Epoch 278/500, Train Loss: 0.3024, Val Loss: 0.2250, Val Accuracy: 0.9194
# No improvement in validation loss for 21 epoch(s).
# Epoch 279/500, Train Loss: 0.3020, Val Loss: 0.2288, Val Accuracy: 0.9178
# No improvement in validation loss for 22 epoch(s).
# Epoch 280/500, Train Loss: 0.3004, Val Loss: 0.2290, Val Accuracy: 0.9181
# No improvement in validation loss for 23 epoch(s).
# Epoch 281/500, Train Loss: 0.3006, Val Loss: 0.2288, Val Accuracy: 0.9179
# No improvement in validation loss for 24 epoch(s).
# Epoch 282/500, Train Loss: 0.3000, Val Loss: 0.2314, Val Accuracy: 0.9182
# No improvement in validation loss for 25 epoch(s).
# Epoch 283/500, Train Loss: 0.3016, Val Loss: 0.2342, Val Accuracy: 0.9154
# No improvement in validation loss for 26 epoch(s).
# Epoch 284/500, Train Loss: 0.2959, Val Loss: 0.2290, Val Accuracy: 0.9173
# No improvement in validation loss for 27 epoch(s).
# Epoch 285/500, Train Loss: 0.3019, Val Loss: 0.2245, Val Accuracy: 0.9191
# No improvement in validation loss for 28 epoch(s).
# Epoch 286/500, Train Loss: 0.2990, Val Loss: 0.2233, Val Accuracy: 0.9203
# Validation loss decreased, saving the model...
# Epoch 287/500, Train Loss: 0.3017, Val Loss: 0.2243, Val Accuracy: 0.9203
# No improvement in validation loss for 1 epoch(s).
# Epoch 288/500, Train Loss: 0.3009, Val Loss: 0.2344, Val Accuracy: 0.9176
# No improvement in validation loss for 2 epoch(s).
# Epoch 289/500, Train Loss: 0.3002, Val Loss: 0.2256, Val Accuracy: 0.9191
# No improvement in validation loss for 3 epoch(s).
# Epoch 290/500, Train Loss: 0.2972, Val Loss: 0.2370, Val Accuracy: 0.9142
# No improvement in validation loss for 4 epoch(s).
# Epoch 291/500, Train Loss: 0.2975, Val Loss: 0.2255, Val Accuracy: 0.9214
# No improvement in validation loss for 5 epoch(s).
# Epoch 292/500, Train Loss: 0.2978, Val Loss: 0.2379, Val Accuracy: 0.9146
# No improvement in validation loss for 6 epoch(s).
# Epoch 293/500, Train Loss: 0.3002, Val Loss: 0.2225, Val Accuracy: 0.9209
# Validation loss decreased, saving the model...
# Epoch 294/500, Train Loss: 0.3004, Val Loss: 0.2293, Val Accuracy: 0.9166
# No improvement in validation loss for 1 epoch(s).
# Epoch 295/500, Train Loss: 0.2991, Val Loss: 0.2234, Val Accuracy: 0.9200
# No improvement in validation loss for 2 epoch(s).
# Epoch 296/500, Train Loss: 0.2998, Val Loss: 0.2512, Val Accuracy: 0.9118
# No improvement in validation loss for 3 epoch(s).
# Epoch 297/500, Train Loss: 0.2977, Val Loss: 0.2367, Val Accuracy: 0.9141
# No improvement in validation loss for 4 epoch(s).
# Epoch 298/500, Train Loss: 0.2984, Val Loss: 0.2341, Val Accuracy: 0.9141
# No improvement in validation loss for 5 epoch(s).
# Epoch 299/500, Train Loss: 0.3002, Val Loss: 0.2505, Val Accuracy: 0.9091
# No improvement in validation loss for 6 epoch(s).
# Epoch 300/500, Train Loss: 0.2998, Val Loss: 0.2294, Val Accuracy: 0.9161
# No improvement in validation loss for 7 epoch(s).
# Epoch 301/500, Train Loss: 0.2971, Val Loss: 0.2357, Val Accuracy: 0.9161
# No improvement in validation loss for 8 epoch(s).
# Epoch 302/500, Train Loss: 0.2975, Val Loss: 0.2222, Val Accuracy: 0.9211
# Validation loss decreased, saving the model...
# Epoch 303/500, Train Loss: 0.3008, Val Loss: 0.2304, Val Accuracy: 0.9167
# No improvement in validation loss for 1 epoch(s).
# Epoch 304/500, Train Loss: 0.2964, Val Loss: 0.2292, Val Accuracy: 0.9173
# No improvement in validation loss for 2 epoch(s).
# Epoch 305/500, Train Loss: 0.2983, Val Loss: 0.2239, Val Accuracy: 0.9205
# No improvement in validation loss for 3 epoch(s).
# Epoch 306/500, Train Loss: 0.2996, Val Loss: 0.2303, Val Accuracy: 0.9188
# No improvement in validation loss for 4 epoch(s).
# Epoch 307/500, Train Loss: 0.2970, Val Loss: 0.2197, Val Accuracy: 0.9216
# Validation loss decreased, saving the model...
# Epoch 308/500, Train Loss: 0.2964, Val Loss: 0.2354, Val Accuracy: 0.9146
# No improvement in validation loss for 1 epoch(s).
# Epoch 309/500, Train Loss: 0.2965, Val Loss: 0.2212, Val Accuracy: 0.9209
# No improvement in validation loss for 2 epoch(s).
# Epoch 310/500, Train Loss: 0.2962, Val Loss: 0.2227, Val Accuracy: 0.9196
# No improvement in validation loss for 3 epoch(s).
# Epoch 311/500, Train Loss: 0.2957, Val Loss: 0.2316, Val Accuracy: 0.9153
# No improvement in validation loss for 4 epoch(s).
# Epoch 312/500, Train Loss: 0.2959, Val Loss: 0.2313, Val Accuracy: 0.9202
# No improvement in validation loss for 5 epoch(s).
# Epoch 313/500, Train Loss: 0.2974, Val Loss: 0.2269, Val Accuracy: 0.9175
# No improvement in validation loss for 6 epoch(s).
# Epoch 314/500, Train Loss: 0.2986, Val Loss: 0.2277, Val Accuracy: 0.9172
# No improvement in validation loss for 7 epoch(s).
# Epoch 315/500, Train Loss: 0.2948, Val Loss: 0.2224, Val Accuracy: 0.9208
# No improvement in validation loss for 8 epoch(s).
# Epoch 316/500, Train Loss: 0.2959, Val Loss: 0.2438, Val Accuracy: 0.9149
# No improvement in validation loss for 9 epoch(s).
# Epoch 317/500, Train Loss: 0.2980, Val Loss: 0.2238, Val Accuracy: 0.9197
# No improvement in validation loss for 10 epoch(s).
# Epoch 318/500, Train Loss: 0.2959, Val Loss: 0.2293, Val Accuracy: 0.9166
# No improvement in validation loss for 11 epoch(s).
# Epoch 319/500, Train Loss: 0.2949, Val Loss: 0.2434, Val Accuracy: 0.9151
# No improvement in validation loss for 12 epoch(s).
# Epoch 320/500, Train Loss: 0.2972, Val Loss: 0.2318, Val Accuracy: 0.9163
# No improvement in validation loss for 13 epoch(s).
# Epoch 321/500, Train Loss: 0.2937, Val Loss: 0.2256, Val Accuracy: 0.9181
# No improvement in validation loss for 14 epoch(s).
# Epoch 322/500, Train Loss: 0.2973, Val Loss: 0.2236, Val Accuracy: 0.9189
# No improvement in validation loss for 15 epoch(s).
# Epoch 323/500, Train Loss: 0.2947, Val Loss: 0.2353, Val Accuracy: 0.9142
# No improvement in validation loss for 16 epoch(s).
# Epoch 324/500, Train Loss: 0.2931, Val Loss: 0.2256, Val Accuracy: 0.9201
# No improvement in validation loss for 17 epoch(s).
# Epoch 325/500, Train Loss: 0.2936, Val Loss: 0.2512, Val Accuracy: 0.9102
# No improvement in validation loss for 18 epoch(s).
# Epoch 326/500, Train Loss: 0.2958, Val Loss: 0.2299, Val Accuracy: 0.9173
# No improvement in validation loss for 19 epoch(s).
# Epoch 327/500, Train Loss: 0.2956, Val Loss: 0.2264, Val Accuracy: 0.9204
# No improvement in validation loss for 20 epoch(s).
# Epoch 328/500, Train Loss: 0.2968, Val Loss: 0.2324, Val Accuracy: 0.9170
# No improvement in validation loss for 21 epoch(s).
# Epoch 329/500, Train Loss: 0.2941, Val Loss: 0.2273, Val Accuracy: 0.9180
# No improvement in validation loss for 22 epoch(s).
# Epoch 330/500, Train Loss: 0.2953, Val Loss: 0.2351, Val Accuracy: 0.9158
# No improvement in validation loss for 23 epoch(s).
# Epoch 331/500, Train Loss: 0.2947, Val Loss: 0.2290, Val Accuracy: 0.9174
# No improvement in validation loss for 24 epoch(s).
# Epoch 332/500, Train Loss: 0.2955, Val Loss: 0.2206, Val Accuracy: 0.9217
# No improvement in validation loss for 25 epoch(s).
# Epoch 333/500, Train Loss: 0.2939, Val Loss: 0.2204, Val Accuracy: 0.9210
# No improvement in validation loss for 26 epoch(s).
# Epoch 334/500, Train Loss: 0.2968, Val Loss: 0.2257, Val Accuracy: 0.9182
# No improvement in validation loss for 27 epoch(s).
# Epoch 335/500, Train Loss: 0.2932, Val Loss: 0.2275, Val Accuracy: 0.9196
# No improvement in validation loss for 28 epoch(s).
# Epoch 336/500, Train Loss: 0.2936, Val Loss: 0.2441, Val Accuracy: 0.9110
# No improvement in validation loss for 29 epoch(s).
# Epoch 337/500, Train Loss: 0.2936, Val Loss: 0.2254, Val Accuracy: 0.9185
# No improvement in validation loss for 30 epoch(s).
# Epoch 338/500, Train Loss: 0.2936, Val Loss: 0.2197, Val Accuracy: 0.9219
# Validation loss decreased, saving the model...
# Epoch 339/500, Train Loss: 0.2931, Val Loss: 0.2281, Val Accuracy: 0.9188
# No improvement in validation loss for 1 epoch(s).
# Epoch 340/500, Train Loss: 0.2948, Val Loss: 0.2307, Val Accuracy: 0.9149
# No improvement in validation loss for 2 epoch(s).
# Epoch 341/500, Train Loss: 0.2921, Val Loss: 0.2228, Val Accuracy: 0.9200
# No improvement in validation loss for 3 epoch(s).
# Epoch 342/500, Train Loss: 0.2926, Val Loss: 0.2179, Val Accuracy: 0.9228
# Validation loss decreased, saving the model...
# Epoch 343/500, Train Loss: 0.2940, Val Loss: 0.2303, Val Accuracy: 0.9163
# No improvement in validation loss for 1 epoch(s).
# Epoch 344/500, Train Loss: 0.2925, Val Loss: 0.2224, Val Accuracy: 0.9214
# No improvement in validation loss for 2 epoch(s).
# Epoch 345/500, Train Loss: 0.2928, Val Loss: 0.2163, Val Accuracy: 0.9231
# Validation loss decreased, saving the model...
# Epoch 346/500, Train Loss: 0.2933, Val Loss: 0.2212, Val Accuracy: 0.9214
# No improvement in validation loss for 1 epoch(s).
# Epoch 347/500, Train Loss: 0.2925, Val Loss: 0.2251, Val Accuracy: 0.9203
# No improvement in validation loss for 2 epoch(s).
# Epoch 348/500, Train Loss: 0.2939, Val Loss: 0.2246, Val Accuracy: 0.9180
# No improvement in validation loss for 3 epoch(s).
# Epoch 349/500, Train Loss: 0.2888, Val Loss: 0.2212, Val Accuracy: 0.9207
# No improvement in validation loss for 4 epoch(s).
# Epoch 350/500, Train Loss: 0.2939, Val Loss: 0.2279, Val Accuracy: 0.9193
# No improvement in validation loss for 5 epoch(s).
# Epoch 351/500, Train Loss: 0.2902, Val Loss: 0.2247, Val Accuracy: 0.9185
# No improvement in validation loss for 6 epoch(s).
# Epoch 352/500, Train Loss: 0.2895, Val Loss: 0.2286, Val Accuracy: 0.9180
# No improvement in validation loss for 7 epoch(s).
# Epoch 353/500, Train Loss: 0.2902, Val Loss: 0.2310, Val Accuracy: 0.9156
# No improvement in validation loss for 8 epoch(s).
# Epoch 354/500, Train Loss: 0.2921, Val Loss: 0.2193, Val Accuracy: 0.9216
# No improvement in validation loss for 9 epoch(s).
# Epoch 355/500, Train Loss: 0.2921, Val Loss: 0.2214, Val Accuracy: 0.9222
# No improvement in validation loss for 10 epoch(s).
# Epoch 356/500, Train Loss: 0.2894, Val Loss: 0.2440, Val Accuracy: 0.9133
# No improvement in validation loss for 11 epoch(s).
# Epoch 357/500, Train Loss: 0.2905, Val Loss: 0.2193, Val Accuracy: 0.9209
# No improvement in validation loss for 12 epoch(s).
# Epoch 358/500, Train Loss: 0.2936, Val Loss: 0.2219, Val Accuracy: 0.9225
# No improvement in validation loss for 13 epoch(s).
# Epoch 359/500, Train Loss: 0.2891, Val Loss: 0.2293, Val Accuracy: 0.9166
# No improvement in validation loss for 14 epoch(s).
# Epoch 360/500, Train Loss: 0.2924, Val Loss: 0.2230, Val Accuracy: 0.9218
# No improvement in validation loss for 15 epoch(s).
# Epoch 361/500, Train Loss: 0.2902, Val Loss: 0.2328, Val Accuracy: 0.9159
# No improvement in validation loss for 16 epoch(s).
# Epoch 362/500, Train Loss: 0.2916, Val Loss: 0.2226, Val Accuracy: 0.9189
# No improvement in validation loss for 17 epoch(s).
# Epoch 363/500, Train Loss: 0.2897, Val Loss: 0.2270, Val Accuracy: 0.9203
# No improvement in validation loss for 18 epoch(s).
# Epoch 364/500, Train Loss: 0.2906, Val Loss: 0.2273, Val Accuracy: 0.9163
# No improvement in validation loss for 19 epoch(s).
# Epoch 365/500, Train Loss: 0.2911, Val Loss: 0.2179, Val Accuracy: 0.9226
# No improvement in validation loss for 20 epoch(s).
# Epoch 366/500, Train Loss: 0.2895, Val Loss: 0.2202, Val Accuracy: 0.9207
# No improvement in validation loss for 21 epoch(s).
# Epoch 367/500, Train Loss: 0.2875, Val Loss: 0.2183, Val Accuracy: 0.9220
# No improvement in validation loss for 22 epoch(s).
# Epoch 368/500, Train Loss: 0.2918, Val Loss: 0.2263, Val Accuracy: 0.9187
# No improvement in validation loss for 23 epoch(s).
# Epoch 369/500, Train Loss: 0.2906, Val Loss: 0.2223, Val Accuracy: 0.9197
# No improvement in validation loss for 24 epoch(s).
# Epoch 370/500, Train Loss: 0.2898, Val Loss: 0.2298, Val Accuracy: 0.9183
# No improvement in validation loss for 25 epoch(s).
# Epoch 371/500, Train Loss: 0.2888, Val Loss: 0.2267, Val Accuracy: 0.9194
# No improvement in validation loss for 26 epoch(s).
# Epoch 372/500, Train Loss: 0.2912, Val Loss: 0.2256, Val Accuracy: 0.9186
# No improvement in validation loss for 27 epoch(s).
# Epoch 373/500, Train Loss: 0.2878, Val Loss: 0.2574, Val Accuracy: 0.9065
# No improvement in validation loss for 28 epoch(s).
# Epoch 374/500, Train Loss: 0.2897, Val Loss: 0.2204, Val Accuracy: 0.9218
# No improvement in validation loss for 29 epoch(s).
# Epoch 375/500, Train Loss: 0.2879, Val Loss: 0.2294, Val Accuracy: 0.9171
# No improvement in validation loss for 30 epoch(s).
# Epoch 376/500, Train Loss: 0.2890, Val Loss: 0.2396, Val Accuracy: 0.9152
# No improvement in validation loss for 31 epoch(s).
# Epoch 377/500, Train Loss: 0.2898, Val Loss: 0.2207, Val Accuracy: 0.9227
# No improvement in validation loss for 32 epoch(s).
# Epoch 378/500, Train Loss: 0.2896, Val Loss: 0.2221, Val Accuracy: 0.9214
# No improvement in validation loss for 33 epoch(s).
# Epoch 379/500, Train Loss: 0.2897, Val Loss: 0.2185, Val Accuracy: 0.9219
# No improvement in validation loss for 34 epoch(s).
# Epoch 380/500, Train Loss: 0.2901, Val Loss: 0.2232, Val Accuracy: 0.9191
# No improvement in validation loss for 35 epoch(s).
# Epoch 381/500, Train Loss: 0.2873, Val Loss: 0.2288, Val Accuracy: 0.9182
# No improvement in validation loss for 36 epoch(s).
# Epoch 382/500, Train Loss: 0.2917, Val Loss: 0.2306, Val Accuracy: 0.9180
# No improvement in validation loss for 37 epoch(s).
# Epoch 383/500, Train Loss: 0.2871, Val Loss: 0.2209, Val Accuracy: 0.9214
# No improvement in validation loss for 38 epoch(s).
# Epoch 384/500, Train Loss: 0.2882, Val Loss: 0.2224, Val Accuracy: 0.9227
# No improvement in validation loss for 39 epoch(s).
# Epoch 385/500, Train Loss: 0.2886, Val Loss: 0.2270, Val Accuracy: 0.9180
# No improvement in validation loss for 40 epoch(s).
# Epoch 386/500, Train Loss: 0.2873, Val Loss: 0.2154, Val Accuracy: 0.9237
# Validation loss decreased, saving the model...
# Epoch 387/500, Train Loss: 0.2880, Val Loss: 0.2195, Val Accuracy: 0.9206
# No improvement in validation loss for 1 epoch(s).
# Epoch 388/500, Train Loss: 0.2877, Val Loss: 0.2278, Val Accuracy: 0.9188
# No improvement in validation loss for 2 epoch(s).
# Epoch 389/500, Train Loss: 0.2873, Val Loss: 0.2184, Val Accuracy: 0.9214
# No improvement in validation loss for 3 epoch(s).
# Epoch 390/500, Train Loss: 0.2853, Val Loss: 0.2161, Val Accuracy: 0.9230
# No improvement in validation loss for 4 epoch(s).
# Epoch 391/500, Train Loss: 0.2874, Val Loss: 0.2211, Val Accuracy: 0.9205
# No improvement in validation loss for 5 epoch(s).
# Epoch 392/500, Train Loss: 0.2880, Val Loss: 0.2201, Val Accuracy: 0.9240
# No improvement in validation loss for 6 epoch(s).
# Epoch 393/500, Train Loss: 0.2846, Val Loss: 0.2197, Val Accuracy: 0.9216
# No improvement in validation loss for 7 epoch(s).
# Epoch 394/500, Train Loss: 0.2858, Val Loss: 0.2279, Val Accuracy: 0.9178
# No improvement in validation loss for 8 epoch(s).
# Epoch 395/500, Train Loss: 0.2869, Val Loss: 0.2225, Val Accuracy: 0.9196
# No improvement in validation loss for 9 epoch(s).
# Epoch 396/500, Train Loss: 0.2870, Val Loss: 0.2265, Val Accuracy: 0.9175
# No improvement in validation loss for 10 epoch(s).
# Epoch 397/500, Train Loss: 0.2859, Val Loss: 0.2204, Val Accuracy: 0.9236
# No improvement in validation loss for 11 epoch(s).
# Epoch 398/500, Train Loss: 0.2867, Val Loss: 0.2180, Val Accuracy: 0.9219
# No improvement in validation loss for 12 epoch(s).
# Epoch 399/500, Train Loss: 0.2849, Val Loss: 0.2163, Val Accuracy: 0.9236
# No improvement in validation loss for 13 epoch(s).
# Epoch 400/500, Train Loss: 0.2850, Val Loss: 0.2543, Val Accuracy: 0.9033
# No improvement in validation loss for 14 epoch(s).
# Epoch 401/500, Train Loss: 0.2850, Val Loss: 0.2214, Val Accuracy: 0.9193
# No improvement in validation loss for 15 epoch(s).
# Epoch 402/500, Train Loss: 0.2850, Val Loss: 0.2279, Val Accuracy: 0.9169
# No improvement in validation loss for 16 epoch(s).
# Epoch 403/500, Train Loss: 0.2839, Val Loss: 0.2248, Val Accuracy: 0.9184
# No improvement in validation loss for 17 epoch(s).
# Epoch 404/500, Train Loss: 0.2838, Val Loss: 0.2268, Val Accuracy: 0.9173
# No improvement in validation loss for 18 epoch(s).
# Epoch 405/500, Train Loss: 0.2884, Val Loss: 0.2307, Val Accuracy: 0.9168
# No improvement in validation loss for 19 epoch(s).
# Epoch 406/500, Train Loss: 0.2838, Val Loss: 0.2142, Val Accuracy: 0.9244
# Validation loss decreased, saving the model...
# Epoch 407/500, Train Loss: 0.2821, Val Loss: 0.2202, Val Accuracy: 0.9199
# No improvement in validation loss for 1 epoch(s).
# Epoch 408/500, Train Loss: 0.2847, Val Loss: 0.2193, Val Accuracy: 0.9206
# No improvement in validation loss for 2 epoch(s).
# Epoch 409/500, Train Loss: 0.2840, Val Loss: 0.2139, Val Accuracy: 0.9227
# Validation loss decreased, saving the model...
# Epoch 410/500, Train Loss: 0.2841, Val Loss: 0.2199, Val Accuracy: 0.9203
# No improvement in validation loss for 1 epoch(s).
# Epoch 411/500, Train Loss: 0.2852, Val Loss: 0.2253, Val Accuracy: 0.9169
# No improvement in validation loss for 2 epoch(s).
# Epoch 412/500, Train Loss: 0.2834, Val Loss: 0.2200, Val Accuracy: 0.9202
# No improvement in validation loss for 3 epoch(s).
# Epoch 413/500, Train Loss: 0.2851, Val Loss: 0.2135, Val Accuracy: 0.9234
# Validation loss decreased, saving the model...
# Epoch 414/500, Train Loss: 0.2826, Val Loss: 0.2185, Val Accuracy: 0.9206
# No improvement in validation loss for 1 epoch(s).
# Epoch 415/500, Train Loss: 0.2860, Val Loss: 0.2174, Val Accuracy: 0.9201
# No improvement in validation loss for 2 epoch(s).
# Epoch 416/500, Train Loss: 0.2860, Val Loss: 0.2166, Val Accuracy: 0.9226
# No improvement in validation loss for 3 epoch(s).
# Epoch 417/500, Train Loss: 0.2860, Val Loss: 0.2221, Val Accuracy: 0.9200
# No improvement in validation loss for 4 epoch(s).
# Epoch 418/500, Train Loss: 0.2837, Val Loss: 0.2214, Val Accuracy: 0.9196
# No improvement in validation loss for 5 epoch(s).
# Epoch 419/500, Train Loss: 0.2834, Val Loss: 0.2202, Val Accuracy: 0.9197
# No improvement in validation loss for 6 epoch(s).
# Epoch 420/500, Train Loss: 0.2840, Val Loss: 0.2222, Val Accuracy: 0.9209
# No improvement in validation loss for 7 epoch(s).
# Epoch 421/500, Train Loss: 0.2859, Val Loss: 0.2439, Val Accuracy: 0.9102
# No improvement in validation loss for 8 epoch(s).
# Epoch 422/500, Train Loss: 0.2833, Val Loss: 0.2199, Val Accuracy: 0.9199
# No improvement in validation loss for 9 epoch(s).
# Epoch 423/500, Train Loss: 0.2824, Val Loss: 0.2153, Val Accuracy: 0.9239
# No improvement in validation loss for 10 epoch(s).
# Epoch 424/500, Train Loss: 0.2841, Val Loss: 0.2285, Val Accuracy: 0.9169
# No improvement in validation loss for 11 epoch(s).
# Epoch 425/500, Train Loss: 0.2832, Val Loss: 0.2185, Val Accuracy: 0.9219
# No improvement in validation loss for 12 epoch(s).
# Epoch 426/500, Train Loss: 0.2827, Val Loss: 0.2195, Val Accuracy: 0.9207
# No improvement in validation loss for 13 epoch(s).
# Epoch 427/500, Train Loss: 0.2834, Val Loss: 0.2517, Val Accuracy: 0.9080
# No improvement in validation loss for 14 epoch(s).
# Epoch 428/500, Train Loss: 0.2825, Val Loss: 0.2230, Val Accuracy: 0.9184
# No improvement in validation loss for 15 epoch(s).
# Epoch 429/500, Train Loss: 0.2822, Val Loss: 0.2177, Val Accuracy: 0.9207
# No improvement in validation loss for 16 epoch(s).
# Epoch 430/500, Train Loss: 0.2809, Val Loss: 0.2157, Val Accuracy: 0.9221
# No improvement in validation loss for 17 epoch(s).
# Epoch 431/500, Train Loss: 0.2806, Val Loss: 0.2243, Val Accuracy: 0.9181
# No improvement in validation loss for 18 epoch(s).
# Epoch 432/500, Train Loss: 0.2826, Val Loss: 0.2178, Val Accuracy: 0.9231
# No improvement in validation loss for 19 epoch(s).
# Epoch 433/500, Train Loss: 0.2794, Val Loss: 0.2213, Val Accuracy: 0.9201
# No improvement in validation loss for 20 epoch(s).
# Epoch 434/500, Train Loss: 0.2851, Val Loss: 0.2173, Val Accuracy: 0.9212
# No improvement in validation loss for 21 epoch(s).
# Epoch 435/500, Train Loss: 0.2805, Val Loss: 0.2255, Val Accuracy: 0.9175
# No improvement in validation loss for 22 epoch(s).
# Epoch 436/500, Train Loss: 0.2803, Val Loss: 0.2242, Val Accuracy: 0.9189
# No improvement in validation loss for 23 epoch(s).
# Epoch 437/500, Train Loss: 0.2838, Val Loss: 0.2154, Val Accuracy: 0.9218
# No improvement in validation loss for 24 epoch(s).
# Epoch 438/500, Train Loss: 0.2806, Val Loss: 0.2203, Val Accuracy: 0.9202
# No improvement in validation loss for 25 epoch(s).
# Epoch 439/500, Train Loss: 0.2808, Val Loss: 0.2251, Val Accuracy: 0.9187
# No improvement in validation loss for 26 epoch(s).
# Epoch 440/500, Train Loss: 0.2804, Val Loss: 0.2132, Val Accuracy: 0.9242
# Validation loss decreased, saving the model...
# Epoch 441/500, Train Loss: 0.2823, Val Loss: 0.2151, Val Accuracy: 0.9219
# No improvement in validation loss for 1 epoch(s).
# Epoch 442/500, Train Loss: 0.2814, Val Loss: 0.2295, Val Accuracy: 0.9180
# No improvement in validation loss for 2 epoch(s).
# Epoch 443/500, Train Loss: 0.2802, Val Loss: 0.2138, Val Accuracy: 0.9251
# No improvement in validation loss for 3 epoch(s).
# Epoch 444/500, Train Loss: 0.2799, Val Loss: 0.2205, Val Accuracy: 0.9209
# No improvement in validation loss for 4 epoch(s).
# Epoch 445/500, Train Loss: 0.2826, Val Loss: 0.2195, Val Accuracy: 0.9208
# No improvement in validation loss for 5 epoch(s).
# Epoch 446/500, Train Loss: 0.2841, Val Loss: 0.2116, Val Accuracy: 0.9236
# Validation loss decreased, saving the model...
# Epoch 447/500, Train Loss: 0.2812, Val Loss: 0.2223, Val Accuracy: 0.9210
# No improvement in validation loss for 1 epoch(s).
# Epoch 448/500, Train Loss: 0.2826, Val Loss: 0.2126, Val Accuracy: 0.9243
# No improvement in validation loss for 2 epoch(s).
# Epoch 449/500, Train Loss: 0.2804, Val Loss: 0.2180, Val Accuracy: 0.9213
# No improvement in validation loss for 3 epoch(s).
# Epoch 450/500, Train Loss: 0.2815, Val Loss: 0.2436, Val Accuracy: 0.9116
# No improvement in validation loss for 4 epoch(s).
# Epoch 451/500, Train Loss: 0.2779, Val Loss: 0.2326, Val Accuracy: 0.9175
# No improvement in validation loss for 5 epoch(s).
# Epoch 452/500, Train Loss: 0.2802, Val Loss: 0.2179, Val Accuracy: 0.9234
# No improvement in validation loss for 6 epoch(s).
# Epoch 453/500, Train Loss: 0.2813, Val Loss: 0.2139, Val Accuracy: 0.9231
# No improvement in validation loss for 7 epoch(s).
# Epoch 454/500, Train Loss: 0.2812, Val Loss: 0.2210, Val Accuracy: 0.9215
# No improvement in validation loss for 8 epoch(s).
# Epoch 455/500, Train Loss: 0.2802, Val Loss: 0.2230, Val Accuracy: 0.9201
# No improvement in validation loss for 9 epoch(s).
# Epoch 456/500, Train Loss: 0.2757, Val Loss: 0.2210, Val Accuracy: 0.9222
# No improvement in validation loss for 10 epoch(s).
# Epoch 457/500, Train Loss: 0.2799, Val Loss: 0.2248, Val Accuracy: 0.9190
# No improvement in validation loss for 11 epoch(s).
# Epoch 458/500, Train Loss: 0.2800, Val Loss: 0.2296, Val Accuracy: 0.9156
# No improvement in validation loss for 12 epoch(s).
# Epoch 459/500, Train Loss: 0.2812, Val Loss: 0.2178, Val Accuracy: 0.9215
# No improvement in validation loss for 13 epoch(s).
# Epoch 460/500, Train Loss: 0.2785, Val Loss: 0.2111, Val Accuracy: 0.9246
# Validation loss decreased, saving the model...
# Epoch 461/500, Train Loss: 0.2837, Val Loss: 0.2264, Val Accuracy: 0.9178
# No improvement in validation loss for 1 epoch(s).
# Epoch 462/500, Train Loss: 0.2803, Val Loss: 0.2145, Val Accuracy: 0.9219
# No improvement in validation loss for 2 epoch(s).
# Epoch 463/500, Train Loss: 0.2794, Val Loss: 0.2120, Val Accuracy: 0.9254
# No improvement in validation loss for 3 epoch(s).
# Epoch 464/500, Train Loss: 0.2793, Val Loss: 0.2284, Val Accuracy: 0.9169
# No improvement in validation loss for 4 epoch(s).
# Epoch 465/500, Train Loss: 0.2794, Val Loss: 0.2206, Val Accuracy: 0.9201
# No improvement in validation loss for 5 epoch(s).
# Epoch 466/500, Train Loss: 0.2809, Val Loss: 0.2312, Val Accuracy: 0.9184
# No improvement in validation loss for 6 epoch(s).
# Epoch 467/500, Train Loss: 0.2792, Val Loss: 0.2185, Val Accuracy: 0.9240
# No improvement in validation loss for 7 epoch(s).
# Epoch 468/500, Train Loss: 0.2794, Val Loss: 0.2136, Val Accuracy: 0.9231
# No improvement in validation loss for 8 epoch(s).
# Epoch 469/500, Train Loss: 0.2800, Val Loss: 0.2266, Val Accuracy: 0.9189
# No improvement in validation loss for 9 epoch(s).
# Epoch 470/500, Train Loss: 0.2806, Val Loss: 0.2078, Val Accuracy: 0.9266
# Validation loss decreased, saving the model...
# Epoch 471/500, Train Loss: 0.2774, Val Loss: 0.2384, Val Accuracy: 0.9179
# No improvement in validation loss for 1 epoch(s).
# Epoch 472/500, Train Loss: 0.2792, Val Loss: 0.2146, Val Accuracy: 0.9214
# No improvement in validation loss for 2 epoch(s).
# Epoch 473/500, Train Loss: 0.2791, Val Loss: 0.2143, Val Accuracy: 0.9217
# No improvement in validation loss for 3 epoch(s).
# Epoch 474/500, Train Loss: 0.2815, Val Loss: 0.2206, Val Accuracy: 0.9205
# No improvement in validation loss for 4 epoch(s).
# Epoch 475/500, Train Loss: 0.2761, Val Loss: 0.2221, Val Accuracy: 0.9208
# No improvement in validation loss for 5 epoch(s).
# Epoch 476/500, Train Loss: 0.2798, Val Loss: 0.2155, Val Accuracy: 0.9232
# No improvement in validation loss for 6 epoch(s).
# Epoch 477/500, Train Loss: 0.2768, Val Loss: 0.2120, Val Accuracy: 0.9243
# No improvement in validation loss for 7 epoch(s).
# Epoch 478/500, Train Loss: 0.2765, Val Loss: 0.2191, Val Accuracy: 0.9204
# No improvement in validation loss for 8 epoch(s).
# Epoch 479/500, Train Loss: 0.2810, Val Loss: 0.2205, Val Accuracy: 0.9200
# No improvement in validation loss for 9 epoch(s).
# Epoch 480/500, Train Loss: 0.2796, Val Loss: 0.2113, Val Accuracy: 0.9245
# No improvement in validation loss for 10 epoch(s).
# Epoch 481/500, Train Loss: 0.2775, Val Loss: 0.2125, Val Accuracy: 0.9225
# No improvement in validation loss for 11 epoch(s).
# Epoch 482/500, Train Loss: 0.2777, Val Loss: 0.2221, Val Accuracy: 0.9191
# No improvement in validation loss for 12 epoch(s).
# Epoch 483/500, Train Loss: 0.2789, Val Loss: 0.2134, Val Accuracy: 0.9242
# No improvement in validation loss for 13 epoch(s).
# Epoch 484/500, Train Loss: 0.2757, Val Loss: 0.2051, Val Accuracy: 0.9272
# Validation loss decreased, saving the model...
# Epoch 485/500, Train Loss: 0.2744, Val Loss: 0.2196, Val Accuracy: 0.9220
# No improvement in validation loss for 1 epoch(s).
# Epoch 486/500, Train Loss: 0.2767, Val Loss: 0.2265, Val Accuracy: 0.9185
# No improvement in validation loss for 2 epoch(s).
# Epoch 487/500, Train Loss: 0.2773, Val Loss: 0.2237, Val Accuracy: 0.9201
# No improvement in validation loss for 3 epoch(s).
# Epoch 488/500, Train Loss: 0.2764, Val Loss: 0.2236, Val Accuracy: 0.9182
# No improvement in validation loss for 4 epoch(s).
# Epoch 489/500, Train Loss: 0.2784, Val Loss: 0.2080, Val Accuracy: 0.9269
# No improvement in validation loss for 5 epoch(s).
# Epoch 490/500, Train Loss: 0.2754, Val Loss: 0.2199, Val Accuracy: 0.9203
# No improvement in validation loss for 6 epoch(s).
# Epoch 491/500, Train Loss: 0.2805, Val Loss: 0.2360, Val Accuracy: 0.9169
# No improvement in validation loss for 7 epoch(s).
# Epoch 492/500, Train Loss: 0.2787, Val Loss: 0.2080, Val Accuracy: 0.9254
# No improvement in validation loss for 8 epoch(s).
# Epoch 493/500, Train Loss: 0.2728, Val Loss: 0.2183, Val Accuracy: 0.9222
# No improvement in validation loss for 9 epoch(s).
# Epoch 494/500, Train Loss: 0.2741, Val Loss: 0.2316, Val Accuracy: 0.9142
# No improvement in validation loss for 10 epoch(s).
# Epoch 495/500, Train Loss: 0.2779, Val Loss: 0.2300, Val Accuracy: 0.9161
# No improvement in validation loss for 11 epoch(s).
# Epoch 496/500, Train Loss: 0.2770, Val Loss: 0.2245, Val Accuracy: 0.9186
# No improvement in validation loss for 12 epoch(s).
# Epoch 497/500, Train Loss: 0.2771, Val Loss: 0.2222, Val Accuracy: 0.9184
# No improvement in validation loss for 13 epoch(s).
# Epoch 498/500, Train Loss: 0.2768, Val Loss: 0.2206, Val Accuracy: 0.9187
# No improvement in validation loss for 14 epoch(s).
# Epoch 499/500, Train Loss: 0.2768, Val Loss: 0.2332, Val Accuracy: 0.9142
# No improvement in validation loss for 15 epoch(s).
# Epoch 500/500, Train Loss: 0.2729, Val Loss: 0.2133, Val Accuracy: 0.9267
# No improvement in validation loss for 16 epoch(s).

# %%
print("Training ConvFc Classifier...")
conv_fc_classifier, train_losses_conv_fc, val_losses_conv_fc, val_accuracies_conv_fc = train_classifier(
    model=conv_fc_classifier, 
    train_loader=train_loader, 
    val_loader=val_loader, 
    epochs=500, 
    patience=50, 
    lr=0.00005, 
    device=device
)

print("Training Lightweight ConvFc Classifier...")
light_conv_fc_classifier, light_train_losses_conv_fc, light_val_losses_conv_fc, light_val_accuracies_conv_fc = train_classifier(
    model=light_conv_fc_classifier, 
    train_loader=train_loader, 
    val_loader=val_loader, 
    epochs=500, 
    patience=50, 
    lr=0.00005, 
    device=device
)

print("Training Attention ConvFc Classifier...")
atten_conv_fc_classifier, atten_train_losses_conv_fc, atten_val_losses_conv_fc, atten_val_accuracies_conv_fc = train_classifier(
    model=atten_conv_fc_classifier, 
    train_loader=train_loader, 
    val_loader=val_loader, 
    epochs=500, 
    patience=50, 
    lr=0.00005, 
    device=device
)

# %%
def plot_training_history(train_losses, val_losses, val_accuracies, model_name):
    """
    Plots the training and validation loss and validation accuracy.

    Args:
        train_losses (list): List of training losses per epoch.
        val_losses (list): List of validation losses per epoch.
        val_accuracies (list): List of validation accuracies per epoch.
        model_name (str): Name of the model for labeling.
    """
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(14, 5))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'b-', label='Training Loss')
    plt.plot(epochs, val_losses, 'r-', label='Validation Loss')
    plt.title(f'{model_name} - Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, val_accuracies, 'g-', label='Validation Accuracy')
    plt.title(f'{model_name} - Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_training_history(
    train_losses=light_train_losses_conv_fc,
    val_losses=light_val_losses_conv_fc,
    val_accuracies=light_val_accuracies_conv_fc,
    model_name='light_ConvFcClassifier'
)

plot_training_history(
    train_losses=atten_train_losses_conv_fc,
    val_losses=atten_val_losses_conv_fc,
    val_accuracies=atten_val_accuracies_conv_fc,
    model_name='atten_ConvFcClassifier'
)

plot_training_history(
    train_losses=train_losses_conv_fc,
    val_losses=val_losses_conv_fc,
    val_accuracies=val_accuracies_conv_fc,
    model_name='ConvFcClassifier'
)

# %%
plot_training_history(
    train_losses=train_losses_ams,
    val_losses=val_losses_ams,
    val_accuracies=val_accuracies_ams,
    model_name='ConvFcClassifier'
)

# %%
# Evaluate ConvFcClassifier
atten_mean_test_loss_conv_fc, atten_test_accuracy_conv_fc, atten_classification_errors_conv_fc, atten_outputs_conv_fc = evaluate_classifier(
    model=atten_conv_fc_classifier,
    test_loader=test_loader,
    device=device
)
print(f"atten_ConvFcClassifier - Test Loss: {atten_mean_test_loss_conv_fc:.4f}, Test Accuracy: {atten_test_accuracy_conv_fc:.4f}")


light_mean_test_loss_conv_fc, light_test_accuracy_conv_fc, light_classification_errors_conv_fc, light_outputs_conv_fc = evaluate_classifier(
    model=light_conv_fc_classifier,
    test_loader=test_loader,
    device=device
)
print(f"light_ConvFcClassifier - Test Loss: {light_mean_test_loss_conv_fc:.4f}, Test Accuracy: {light_test_accuracy_conv_fc:.4f}")


mean_test_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc = evaluate_classifier(
    model=conv_fc_classifier,
    test_loader=test_loader,
    device=device
)
print(f"ConvFcClassifier - Test Loss: {mean_test_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}")

# %%
# Evaluate ConvFcClassifier
atten_mean_test_loss_ams, atten_test_accuracy_ams, atten_classification_errors_ams, atten_outputs_ams = evaluate_classifier(
    model=ams_classifier,
    test_loader=test_loader,
    device=device
)
print(f"ams_ConvFcClassifier - Test Loss: {atten_mean_test_loss_ams:.4f}, Test Accuracy: {atten_test_accuracy_ams:.4f}")
# Out:
# ams_ConvFcClassifier - Test Loss: 0.1658, Test Accuracy: 0.9440

# %%
# torch.save(attention_lstm_classifier.state_dict(), './models/4AttentionLSTMClassifier.pth')
# torch.save(conv_fc_classifier.state_dict(), f'./models/{cycle_num}ConvFcClassifier.pth')
# torch.save(atten_conv_fc_classifier.state_dict(), f'./models/{cycle_num}attenConvFcClassifier.pth')
# torch.save(light_conv_fc_classifier.state_dict(), f'./models/{cycle_num}lightConvFcClassifier.pth')
# torch.save(dense_classifier.state_dict(), './models/4DenseClassifier.pth')

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  # Import pandas to handle CSV writing
import torch

def generate_reports(true_labels, predicted_labels, model_name, report_file):
    """
    Generates and writes classification report to a file and confusion matrix to a CSV file.

    Args:
        true_labels (numpy.ndarray): True labels.
        predicted_labels (numpy.ndarray): Predicted labels predicted by the model.
        model_name (str): Name of the model for labeling.
        report_file (file object): Open file to write the report.
    """
    # Write model name header
    report_file.write(f"\n--- {model_name} ---\n\n")
    
    # Combine true and predicted labels to get all labels present in the data
    unique_labels = np.unique(np.concatenate((true_labels, predicted_labels)))
    labels = sorted(unique_labels)
    
    # Invert code_to_label to get label_to_disease mapping
    label_to_disease = {v: k for k, v in code_to_label.items()}
    
    print("Unique labels in data:", labels)
    print("label_to_disease:", label_to_disease)
    
    # Ensure all labels are in label_to_disease
    missing_labels = [label for label in labels if label not in label_to_disease]
    if missing_labels:
        print("The following labels are missing in label_to_disease:", missing_labels)
        # Handle missing labels by adding them with a default name
        for label in missing_labels:
            label_to_disease[label] = f"Unknown Label {label}"
    
    # Generate target_names for labels present in data
    # target_names = [label_to_disease.get(k, f"Label {k}") for k in labels]
    print(true_labels)
    print(predicted_labels)
    print(labels)
    # print(target_names)
    # Generate classification report
    report = classification_report(
        true_labels,
        predicted_labels,
        labels=labels,
        # target_names=target_names,
        zero_division=0
    )
    report_file.write("Classification Report:\n")
    report_file.write(report + "\n")
    
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels, labels=labels)
    
    # Write confusion matrix to a CSV file
    csv_file_path = save_path + f"/{model_name}_confusion_matrix.csv"  # Ensure save_path is defined
    # Convert confusion matrix to DataFrame
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)
    cm_df.to_csv(csv_file_path, encoding='utf-8')
    
    # Optionally, save the confusion matrix as an image
    plt.figure(figsize=(4,4))  # Adjust size to accommodate the number of classes
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title(f'{model_name} - Confusion Matrix')
    plt.tight_layout()
    plt.savefig(save_path + f"/{model_name}_confusion_matrix.png")
    plt.close()

# Open a text file in write mode
with open(save_path + "/confusion_matrices.txt", "w") as f:
    # Retrieve true labels from test_dataset
    true_labels = test_dataset.tensors[1].numpy()
    
    # ConvFcClassifier Reports
    # predicted_labels_conv_fc = torch.argmax(outputs_conv_fc, dim=1).cpu().numpy()
    # generate_reports(true_labels, predicted_labels_conv_fc, "ConvFcClassifier", f)
    
    # If you have other classifiers, you can generate their reports similarly
    # Example for AttentionLSTMClassifier
    predicted_labels_att_lstm = torch.argmax(atten_outputs_conv_fc, dim=1).cpu().numpy()
    generate_reports(true_labels, predicted_labels_att_lstm, "AttentionClassifier", f)

    # predicted_labels_att_lstm = torch.argmax(light_outputs_conv_fc, dim=1).cpu().numpy()
    # generate_reports(true_labels, predicted_labels_att_lstm, "LightClassifier", f)

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd  # Import pandas to handle CSV writing
# import torch
# import numpy as np
# import os

# def generate_reports(true_labels, predicted_labels, model_name, report_file, save_path):
#     """
#     Generates and writes classification report to a file, confusion matrix to a CSV file,
#     and analyzes misclassifications for potential disease groupings.

#     Args:
#         true_labels (numpy.ndarray): True labels.
#         predicted_labels (numpy.ndarray): Predicted labels predicted by the model.
#         model_name (str): Name of the model for labeling.
#         report_file (file object): Open file to write the report.
#         save_path (str): Directory path to save CSV and image files.
#     """
#     # Write model name header
#     report_file.write(f"\n--- {model_name} ---\n\n")
    
#     # Combine true and predicted labels to get all labels present in the data
#     unique_labels = np.unique(np.concatenate((true_labels, predicted_labels)))
#     labels = sorted(unique_labels)
    
#     # Invert code_to_label to get label_to_disease mapping
#     label_to_disease = {v: k for k, v in code_to_label.items()}
    
#     print("Unique labels in data:", labels)
#     print("label_to_disease:", label_to_disease)
    
#     # Ensure all labels are in label_to_disease
#     missing_labels = [label for label in labels if label not in label_to_disease]
#     if missing_labels:
#         print("The following labels are missing in label_to_disease:", missing_labels)
#         # Handle missing labels by adding them with a default name
#         for label in missing_labels:
#             label_to_disease[label] = f"Unknown Label {label}"
    
#     # Generate target_names for labels present in data
#     # target_names = [label_to_disease.get(k, f"Label {k}") for k in labels]
    
#     # Generate classification report
#     report = classification_report(
#         true_labels,
#         predicted_labels,
#         labels=labels,
#         # target_names=target_names,
#         zero_division=0
#     )
#     report_file.write("Classification Report:\n")
#     report_file.write(report + "\n")
    
#     # Generate confusion matrix
#     cm = confusion_matrix(true_labels, predicted_labels, labels=labels)
    
#     # Write confusion matrix to a CSV file
#     csv_file_path = os.path.join(save_path, f"{model_name}_confusion_matrix.csv")
#     cm_df = pd.DataFrame(cm, index=labels, columns=labels)
#     cm_df.to_csv(csv_file_path, encoding='utf-8')
#     print(f"Confusion matrix CSV saved at: {csv_file_path}")
    
#     # Optionally, save the confusion matrix as an image
#     plt.figure(figsize=(20,18))  # Adjust size to accommodate the number of classes
#     sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
#     plt.ylabel('Actual')
#     plt.xlabel('Predicted')
#     plt.title(f'{model_name} - Confusion Matrix')
#     plt.tight_layout()
#     image_file_path = os.path.join(save_path, f"{model_name}_confusion_matrix.png")
#     plt.savefig(image_file_path)
#     plt.close()
#     print(f"Confusion matrix image saved at: {image_file_path}")
    
#     # **Misclassification Analysis**
    
#     # Remove the diagonal to focus on misclassifications
#     cm_no_diag = cm_df.copy()
#     np.fill_diagonal(cm_no_diag.values, 0)
    
#     # Melt the DataFrame to have a long-form table
#     confusion_melted = cm_no_diag.reset_index().melt(id_vars='index', var_name='Predicted', value_name='Count')
#     confusion_melted = confusion_melted.rename(columns={'index': 'Actual'})
    
#     # Sort by Count descending to identify top misclassifications
#     top_misclassifications = confusion_melted.sort_values(by='Count', ascending=False)
    
#     # Display top 10 misclassifications
#     top_10_misclass = top_misclassifications.head(10)
#     print("\nTop 10 Misclassifications:")
#     print(top_10_misclass)
    
#     # Write top misclassifications to the report
#     report_file.write("\nTop 10 Misclassifications Overall:\n")
#     report_file.write(top_10_misclass.to_string(index=False))
    
#     # For each actual disease, find the predicted disease with the highest misclassification
#     top_misclass_per_disease = cm_no_diag.idxmax(axis=1)
#     top_counts = cm_no_diag.max(axis=1)
    
#     top_misclass_per_disease_df = pd.DataFrame({
#         'Actual Disease': cm_no_diag.index,
#         'Most Misclassified As': top_misclass_per_disease.values,
#         'Count': top_counts.values
#     })
    
#     print("\nTop Misclassifications Per Disease:")
#     print(top_misclass_per_disease_df)
    
#     # Write top misclassifications per disease to the report
#     report_file.write("\n\nTop Misclassifications Per Disease:\n")
#     report_file.write(top_misclass_per_disease_df.to_string(index=False))
    
#     # Find mutual confusions: A -> B and B -> A
#     mutual_confusions = []
#     for actual in cm_no_diag.index:
#         predicted = cm_no_diag.loc[actual].idxmax()
#         if actual != predicted:
#             predicted_top = cm_no_diag.loc[predicted].idxmax()
#             if predicted_top == actual:
#                 pair = tuple(sorted([actual, predicted]))
#                 if pair not in mutual_confusions:
#                     mutual_confusions.append(pair)
    
#     print("\nMutual Confusions (Pairs of Diseases):")
#     for pair in mutual_confusions:
#         print(f"{pair[0]} <--> {pair[1]}")
    
#     # Write mutual confusions to the report
#     report_file.write("\n\nMutual Confusions (Pairs of Diseases):\n")
#     if mutual_confusions:
#         for pair in mutual_confusions:
#             report_file.write(f"{pair[0]} <--> {pair[1]}\n")
#     else:
#         report_file.write("No mutual confusions detected.\n")

# %%
# import torch  # Ensure torch is imported if not already

# # Open a text file in write mode for the classification report
# report_txt_path = os.path.join(save_path, "confusion_matrices.txt")
# with open(report_txt_path, "w") as f:
#     # Retrieve true labels from test_dataset
#     true_labels = test_dataset.tensors[1].numpy()
    
#     # ConvFcClassifier Reports
#     predicted_labels_conv_fc = torch.argmax(outputs_conv_fc, dim=1).cpu().numpy()
#     generate_reports(true_labels, predicted_labels_conv_fc, "ConvFcClassifier", f, save_path)
    
# report_txt_path = os.path.join(save_path, "atten_confusion_matrices.txt")
# with open(report_txt_path, "w") as f:
#     # Retrieve true labels from test_dataset
#     true_labels = test_dataset.tensors[1].numpy()
    
#     # ConvFcClassifier Reports
#     atten_predicted_labels_conv_fc = torch.argmax(atten_outputs_conv_fc, dim=1).cpu().numpy()
#     generate_reports(true_labels, predicted_labels_conv_fc, "atten_ConvFcClassifier", f, save_path)

# report_txt_path = os.path.join(save_path, "light_confusion_matrices.txt")
# with open(report_txt_path, "w") as f:
#     # Retrieve true labels from test_dataset
#     true_labels = test_dataset.tensors[1].numpy()
    
#     # ConvFcClassifier Reports
#     light_predicted_labels_conv_fc = torch.argmax(light_outputs_conv_fc, dim=1).cpu().numpy()
#     generate_reports(true_labels, light_predicted_labels_conv_fc, "light_ConvFcClassifier", f, save_path)

# %%
# def evaluate_classifier(model, test_loader, device='cuda'):
#     """
#     Evaluate a classification model on test data.

#     Args:
#         model (nn.Module): The trained classification model.
#         test_loader (DataLoader): DataLoader for test data, yielding (inputs, labels).
#         device (str): Device to perform evaluation on ('cuda' or 'cpu').

#     Returns:
#         float: Mean test loss.
#         float: Test accuracy.
#         list: List of reconstruction (classification) errors per sample.
#         torch.Tensor: Model outputs for the last batch.
#     """
#     criterion = nn.CrossEntropyLoss()
#     model.to(device)
#     test_loss = 0.0
#     correct = 0
#     total = 0
#     classification_errors = []
#     all_outputs = []
#     all_labels = []
#     with torch.no_grad():
#         for batch in test_loader:
#             inputs, labels = batch
#             inputs = inputs.to(device).float()
#             labels = labels.to(device).long()

#             outputs = model(inputs)  # [batch_size, num_classes]
#             loss = criterion(outputs, labels)
#             test_loss += loss.item() * inputs.size(0)

#             # Calculate accuracy
#             _, preds = torch.max(outputs, 1)
#             correct += torch.sum(preds == labels)
#             total += labels.size(0)

#             # Collect classification errors (optional)
#             # Here, we can define error as 1 - accuracy per sample, but CrossEntropyLoss is not per-sample
#             # Alternatively, collect whether each sample was correctly classified
#             errors = (preds != labels).float().cpu().numpy()
#             classification_errors.extend(errors)

#             # Optionally, collect all outputs and labels
#             all_outputs.append(outputs.cpu())
#             all_labels.append(labels.cpu())

#     mean_test_loss = test_loss / len(test_loader.dataset)
#     test_accuracy = correct.double() / total
#     return mean_test_loss, test_accuracy.item(), classification_errors, torch.cat(all_outputs, dim=0)

# %%
import torch
import torch.nn as nn
import time

def evaluate_classifier_time(
    model_advance, 
    model_moderate, 
    model_lightweight, 
    test_loader, 
    device='cpu', 
    cycle_num=2
):
    """
    Evaluate classification models on test data based on BPM thresholds, measure average inference time per sample,
    and track the number of samples in each BPM category.

    Args:
        model_advance (nn.Module): Model to use for BPM > 100.
        model_moderate (nn.Module): Model to use for 40 < BPM ≤ 100.
        model_lightweight (nn.Module): Model to use for BPM ≤ 40.
        test_loader (DataLoader): DataLoader for test data, yielding (inputs, labels).
        device (str): Device to perform evaluation on ('cuda' or 'cpu').
        cycle_num (int): Number of duration features per sample in inputs (default is 2).

    Returns:
        float: Mean test loss.
        float: Test accuracy.
        list: List of classification errors per sample.
        torch.Tensor: Model outputs for all samples.
        float: Average inference time per sample (in milliseconds).
        dict: Counts of samples in each BPM category.
    """
    # Define the loss criterion
    criterion = nn.CrossEntropyLoss()

    # Move all models to the specified device and set to evaluation mode
    models = {
        'advance': model_advance.to(device).eval(),
        'moderate': model_moderate.to(device).eval(),
        'lightweight': model_lightweight.to(device).eval()
    }

    test_loss = 0.0
    correct = 0
    total = 0
    classification_errors = []
    all_outputs = []
    all_labels = []

    # Initialize timing
    total_inference_time = 0.0  # In seconds

    # Initialize counts for each category
    category_counts = {
        'advance': 0,
        'moderate': 0,
        'lightweight': 0
    }

    # Define BPM categories
    def get_bpm_category(bpm):
        # print(bpm)
        if bpm > 0.012:
            return 'advance'
        elif bpm < 0.009:
            return 'lightweight'
        else:
            return 'moderate'

    with torch.no_grad():
        for batch_idx, batch in enumerate(test_loader):
            if len(batch) != 2:
                raise ValueError("Each batch must contain exactly two elements: (inputs, labels).")

            inputs, labels = batch  # inputs shape: [batch_size, channels, features] or [batch_size, features]
        

            # Move inputs and labels to device
            inputs = inputs.to(device).float()
            labels = labels.to(device).long()

            # Extract duration features (last `cycle_num` features)
            if inputs.dim() == 3:
                # For 3D inputs: [batch_size, channels, features]
                durations = inputs[:, :, -cycle_num:]
                ecg_data = inputs[:, :, :-cycle_num]
                # Compute average duration per sample across channels and cycles
                durations = durations.mean(dim=1).mean(dim=1)  # Shape: [batch_size]
            elif inputs.dim() == 2:
                # For 2D inputs: [batch_size, features]
                durations = inputs[:, -cycle_num:]
                ecg_data = inputs[:, :-cycle_num]
                # Compute average duration per sample
                durations = durations.mean(dim=1)  # Shape: [batch_size]
            else:
                raise ValueError("Unsupported input dimensions. Inputs must be 2D or 3D tensors.")

            # Compute BPM: BPM = 60 / average period
            # print(durations)
            bpm = durations  # Shape: [batch_size]

            # Determine categories for each sample
            categories = [get_bpm_category(b) for b in bpm.cpu().numpy()]

            # Update category counts
            for cat in categories:
                category_counts[cat] += 1

            # Initialize masks for each category
            masks = {
                'advance': torch.tensor([cat == 'advance' for cat in categories], device=device),
                'moderate': torch.tensor([cat == 'moderate' for cat in categories], device=device),
                'lightweight': torch.tensor([cat == 'lightweight' for cat in categories], device=device)
            }

            for category, mask in masks.items():
                if torch.sum(mask) == 0:
                    continue  # No samples in this category for the current batch

                # Select samples belonging to the current category
                if ecg_data.dim() == 3:
                    selected_inputs = inputs[mask]  # Shape: [num_selected, channels, features - cycle_num]
                else:
                    selected_inputs = inputs[mask]  # Shape: [num_selected, features - cycle_num]
                selected_labels = labels[mask]

                # Measure inference time
                if device == 'cuda':
                    torch.cuda.synchronize()
                start_time = time.time()

                # Forward pass with the corresponding model
                outputs = models[category](selected_inputs)

                if device == 'cuda':
                    torch.cuda.synchronize()
                end_time = time.time()

                # Calculate inference time for the selected samples
                inference_time = end_time - start_time  # In seconds
                total_inference_time += inference_time

                # Compute loss
                loss = criterion(outputs, selected_labels)
                test_loss += loss.item() * selected_inputs.size(0)

                # Calculate predictions
                _, preds = torch.max(outputs, 1)

                # Update correct predictions and total samples
                correct += torch.sum(preds == selected_labels)
                total += selected_labels.size(0)

                # Collect classification errors (1 for incorrect, 0 for correct)
                errors = (preds != selected_labels).float().cpu().numpy()
                classification_errors.extend(errors)

                # Collect all outputs and labels for further analysis if needed
                all_outputs.append(outputs.cpu())
                all_labels.append(selected_labels.cpu())

    # Compute average inference time per sample
    if total > 0:
        avg_inference_time_per_sample = (total_inference_time / total) * 1000  # Convert to milliseconds
    else:
        avg_inference_time_per_sample = 0.0

    # Compute mean test loss and test accuracy
    mean_test_loss = test_loss / len(test_loader.dataset)
    test_accuracy = correct.double() / total if total > 0 else 0.0

    # Concatenate all outputs into a single tensor
    all_outputs = torch.cat(all_outputs, dim=0) if all_outputs else torch.Tensor()

    return mean_test_loss, test_accuracy.item(), classification_errors, all_outputs, avg_inference_time_per_sample, category_counts, total_inference_time, total

# %%
# Assuming you have the following models defined and loaded:
# - atten_conv_fc_classifier: Model for BPM > 100 (advance)
# - conv_fc_classifier: Model for 40 < BPM ≤ 100 (moderate)
# - light_conv_fc_classifier: Model for BPM ≤ 40 (lightweight)

# Evaluate all three models using the updated function
mean_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc, avg_time_conv_fc, category_counts_conv_fc, total_inference_time, total = evaluate_classifier_time(
    model_advance=atten_conv_fc_classifier,
    model_moderate=conv_fc_classifier,
    model_lightweight=light_conv_fc_classifier,
    test_loader=test_loader,
    device="cpu",
    cycle_num=cycle_num  # Adjust if you have a different number of duration features
)

# Print the overall evaluation metrics
print(f"ConvFcClassifier - Test Loss: {mean_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}, Test Speed: {avg_time_conv_fc:.4f} ms")

# Print the counts of samples in each BPM category
print("Category Counts:")
for category, count in category_counts_conv_fc.items():
    print(f"  {category.capitalize()}: {count} samples")

print("total_inference_time, total: ", total_inference_time, total)

# %%
# Assuming you have the following models defined and loaded:
# - atten_conv_fc_classifier: Model for BPM > 100 (advance)
# - conv_fc_classifier: Model for 40 < BPM ≤ 100 (moderate)
# - light_conv_fc_classifier: Model for BPM ≤ 40 (lightweight)

# Evaluate all three models using the updated function
mean_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc, avg_time_conv_fc, category_counts_conv_fc, total_inference_time, total = evaluate_classifier_time(
    model_advance=light_conv_fc_classifier,
    model_moderate=light_conv_fc_classifier,
    model_lightweight=light_conv_fc_classifier,
    test_loader=test_loader,
    device="cpu",
    cycle_num=cycle_num  # Adjust if you have a different number of duration features
)

# Print the overall evaluation metrics
print(f"ConvFcClassifier - Test Loss: {mean_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}, Test Speed: {avg_time_conv_fc:.4f} ms")

# Print the counts of samples in each BPM category
print("Category Counts:")
for category, count in category_counts_conv_fc.items():
    print(f"  {category.capitalize()}: {count} samples")

print("total_inference_time, total: ", total_inference_time, total)

# %%
# Assuming you have the following models defined and loaded:
# - atten_conv_fc_classifier: Model for BPM > 100 (advance)
# - conv_fc_classifier: Model for 40 < BPM ≤ 100 (moderate)
# - light_conv_fc_classifier: Model for BPM ≤ 40 (lightweight)

# Evaluate all three models using the updated function
mean_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc, avg_time_conv_fc, category_counts_conv_fc, total_inference_time, total = evaluate_classifier_time(
    model_advance=conv_fc_classifier,
    model_moderate=conv_fc_classifier,
    model_lightweight=conv_fc_classifier,
    test_loader=test_loader,
    device="cpu",
    cycle_num=cycle_num  # Adjust if you have a different number of duration features
)

# Print the overall evaluation metrics
print(f"ConvFcClassifier - Test Loss: {mean_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}, Test Speed: {avg_time_conv_fc:.4f} ms")

# Print the counts of samples in each BPM category
print("Category Counts:")
for category, count in category_counts_conv_fc.items():
    print(f"  {category.capitalize()}: {count} samples")

print("total_inference_time, total: ", total_inference_time, total)

# %%
# Assuming you have the following models defined and loaded:
# - atten_conv_fc_classifier: Model for BPM > 100 (advance)
# - conv_fc_classifier: Model for 40 < BPM ≤ 100 (moderate)
# - light_conv_fc_classifier: Model for BPM ≤ 40 (lightweight)

# Evaluate all three models using the updated function
mean_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc, avg_time_conv_fc, category_counts_conv_fc, total_inference_time, total = evaluate_classifier_time(
    model_advance=atten_conv_fc_classifier,
    model_moderate=atten_conv_fc_classifier,
    model_lightweight=atten_conv_fc_classifier,
    test_loader=test_loader,
    device="cpu",
    cycle_num=2  # Adjust if you have a different number of duration features
)

# Print the overall evaluation metrics
print(f"ConvFcClassifier - Test Loss: {mean_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}, Test Speed: {avg_time_conv_fc:.4f} ms")

# Print the counts of samples in each BPM category
print("Category Counts:")
for category, count in category_counts_conv_fc.items():
    print(f"  {category.capitalize()}: {count} samples")

print("total_inference_time, total: ", total_inference_time, total)

# %%
# # Define model parameters
# num_classes = len(code_to_label)  # Number of target classes
# target_length = cycle_num * 8


# # Initialize Classifier Models
# conv_fc_classifier = ConvFcClassifier(num_classes=num_classes, target_length=target_length, cycle_num=cycle_num).to(device)
# atten_conv_fc_classifier = AttentionConvFcClassifier(num_classes=num_classes, target_length=target_length, cycle_num=cycle_num).to(device)
# light_conv_fc_classifier = LightweightConvFcClassifier(num_classes=num_classes, target_length=cycle_num * 4, cycle_num=cycle_num-1).to(device)


# state_dict = torch.load('C:\\ecg_project\\main_system\\disease_classification\\models\\4attenConvFcClassifier.pth')
# atten_conv_fc_classifier.load_state_dict(state_dict)

# state_dict = torch.load('C:\\ecg_project\\main_system\\disease_classification\\models\\4ConvFcClassifier.pth')
# conv_fc_classifier.load_state_dict(state_dict)

# state_dict = torch.load('C:\\ecg_project\\main_system\\disease_classification\\models\\4lightConvFcClassifier.pth')
# light_conv_fc_classifier.load_state_dict(state_dict)

# %%
# # Evaluate ConvFcClassifier
# atten_mean_test_loss_conv_fc, atten_test_accuracy_conv_fc, atten_classification_errors_conv_fc, atten_outputs_conv_fc, atten_speed_conv_fc = evaluate_classifier_time(
#     model=atten_conv_fc_classifier,
#     test_loader=test_loader,
#     device="cpu"
# )
# print(f"atten_ConvFcClassifier - Test Loss: {atten_mean_test_loss_conv_fc:.4f}, Test Accuracy: {atten_test_accuracy_conv_fc:.4f}, Test Speed: {atten_speed_conv_fc:.4f}")


# light_mean_test_loss_conv_fc, light_test_accuracy_conv_fc, light_classification_errors_conv_fc, light_outputs_conv_fc, light_speed_conv_fc = evaluate_classifier_time(
#     model=light_conv_fc_classifier,
#     test_loader=test_loader,
#     device="cpu"
# )
# print(f"light_ConvFcClassifier - Test Loss: {light_mean_test_loss_conv_fc:.4f}, Test Accuracy: {light_test_accuracy_conv_fc:.4f}, Test Speed: {light_speed_conv_fc:.4f}")


# mean_test_loss_conv_fc, test_accuracy_conv_fc, classification_errors_conv_fc, outputs_conv_fc, speed_conv_fc = evaluate_classifier_time(
#     model=conv_fc_classifier,
#     test_loader=test_loader,
#     device="cpu"
# )
# print(f"ConvFcClassifier - Test Loss: {mean_test_loss_conv_fc:.4f}, Test Accuracy: {test_accuracy_conv_fc:.4f}, Test Speed: {speed_conv_fc:.4f}")

# %%
# import pandas as pd
# import numpy as np
# from sklearn.metrics import accuracy_score, precision_recall_fscore_support
# import os
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Define the save_path where your CSV and outputs are stored
# save_path = r"C:\ecg_project\main_system\disease_classification\outputs\20240928162545_cycle_3all"  # Replace with your actual save path

# # Define the path to your confusion matrix CSV
# file_path = os.path.join(save_path, "ConvFcClassifier_confusion_matrix.csv")  # Ensure the file exists here

# # Load the confusion matrix into a pandas DataFrame with all labels as strings
# try:
#     cm_df = pd.read_csv(file_path, index_col=0, dtype=str)  # Read all labels as strings
# except FileNotFoundError:
#     print(f"Error: The file at {file_path} was not found.")
#     exit()
# except pd.errors.EmptyDataError:
#     print("Error: The provided CSV file is empty.")
#     exit()
# except Exception as e:
#     print(f"An unexpected error occurred while reading the CSV: {e}")
#     exit()

# print("Original Confusion Matrix:")
# print(cm_df)

# %%
# # Ensure that all index and column labels are stripped of leading/trailing whitespace
# cm_df.index = cm_df.index.astype(str).str.strip()
# cm_df.columns = cm_df.columns.str.strip()

# # Verify the data types
# print("\nData Types After Conversion:")
# print(f"Index Type: {cm_df.index.dtype}")
# print(f"Columns Type: {cm_df.columns.dtype}")

# # Define the classes to merge and assign new group names
# merge_mapping = {
#     'Merged_Group1': ['164889003', '164890007'],
#     'Merged_Group2': ['425856008', '426761007'],
#     'Merged_Group3': ['426177001', '426783006']
# }

# # List of all classes (as strings)
# all_classes = cm_df.index.tolist()

# # Step 1: Create a mapping from original classes to merged groups
# class_to_group = {}
# for group, classes in merge_mapping.items():
#     for cls in classes:
#         class_to_group[cls] = group

# # Assign remaining classes to themselves
# for cls in all_classes:
#     if cls not in class_to_group:
#         class_to_group[cls] = cls

# # Debug: Print the class_to_group mapping to verify
# print("\nClass to Group Mapping:")
# for cls, group in class_to_group.items():
#     print(f"{cls} --> {group}")

# # Step 2: Create a list of unique groups
# unique_groups = sorted(list(set(class_to_group.values())))

# # Initialize a new confusion matrix DataFrame with merged groups
# merged_cm_df = pd.DataFrame(0, index=unique_groups, columns=unique_groups)

# # Populate the merged confusion matrix
# for actual_class in cm_df.index:
#     actual_group = class_to_group.get(actual_class, 'Unknown Group')  # Safely get the group
#     for predicted_class in cm_df.columns:
#         predicted_group = class_to_group.get(predicted_class, 'Unknown Group')  # Safely get the group
#         count = cm_df.at[actual_class, predicted_class]
#         try:
#             count = int(count)
#         except ValueError:
#             print(f"Warning: Non-integer value '{count}' found for Actual: {actual_class}, Predicted: {predicted_class}. Setting count to 0.")
#             count = 0
#         merged_cm_df.at[actual_group, predicted_group] += count

# print("\nMerged Confusion Matrix:")
# print(merged_cm_df)

# # Flatten the confusion matrix to obtain true and predicted labels
# true_labels_list = []
# predicted_labels_list = []

# for actual_group in merged_cm_df.index:
#     for predicted_group in merged_cm_df.columns:
#         count = merged_cm_df.at[actual_group, predicted_group]
#         if count > 0:
#             true_labels_list.extend([actual_group] * count)
#             predicted_labels_list.extend([predicted_group] * count)

# # Convert lists to numpy arrays
# true_labels_array = np.array(true_labels_list)
# predicted_labels_array = np.array(predicted_labels_list)

# # Calculate accuracy
# accuracy = accuracy_score(true_labels_array, predicted_labels_array)
# print(f"\nAccuracy After Merging: {accuracy:.4f}")

# %%
# # Ensure that all index and column labels are stripped of leading/trailing whitespace
# cm_df.index = cm_df.index.astype(str).str.strip()
# cm_df.columns = cm_df.columns.str.strip()

# # Verify the data types
# print("\nData Types After Conversion:")
# print(f"Index Type: {cm_df.index.dtype}")
# print(f"Columns Type: {cm_df.columns.dtype}")

# # Define the classes to merge and assign new group names
# merge_mapping = {
#     'Merged_Group1': ['164889003', '164890007'],
#     'Merged_Group2': ['425856008', '426761007'],
#     'Merged_Group3': ['426177001', '426783006']
# }

# # List of all classes (as strings)
# all_classes = cm_df.index.tolist()

# # Step 1: Create a mapping from original classes to merged groups
# class_to_group = {}
# for group, classes in merge_mapping.items():
#     for cls in classes:
#         class_to_group[cls] = group

# # Assign remaining classes to themselves
# for cls in all_classes:
#     if cls not in class_to_group:
#         class_to_group[cls] = cls

# # Debug: Print the class_to_group mapping to verify
# print("\nClass to Group Mapping:")
# for cls, group in class_to_group.items():
#     print(f"{cls} --> {group}")

# # Step 2: Create a list of unique groups
# unique_groups = sorted(list(set(class_to_group.values())))

# # Initialize a new confusion matrix DataFrame with merged groups
# merged_cm_df = pd.DataFrame(0, index=unique_groups, columns=unique_groups)

# # Populate the merged confusion matrix
# for actual_class in cm_df.index:
#     actual_group = class_to_group.get(actual_class, 'Unknown Group')  # Safely get the group
#     for predicted_class in cm_df.columns:
#         predicted_group = class_to_group.get(predicted_class, 'Unknown Group')  # Safely get the group
#         count = cm_df.at[actual_class, predicted_class]
#         try:
#             count = int(count)
#         except ValueError:
#             print(f"Warning: Non-integer value '{count}' found for Actual: {actual_class}, Predicted: {predicted_class}. Setting count to 0.")
#             count = 0
#         merged_cm_df.at[actual_group, predicted_group] += count

# print("\nMerged Confusion Matrix:")
# print(merged_cm_df)

# # Flatten the confusion matrix to obtain true and predicted labels
# true_labels_list = []
# predicted_labels_list = []

# for actual_group in merged_cm_df.index:
#     for predicted_group in merged_cm_df.columns:
#         count = merged_cm_df.at[actual_group, predicted_group]
#         if count > 0:
#             true_labels_list.extend([actual_group] * count)
#             predicted_labels_list.extend([predicted_group] * count)

# # Convert lists to numpy arrays
# true_labels_array = np.array(true_labels_list)
# predicted_labels_array = np.array(predicted_labels_list)

# # Calculate accuracy
# accuracy = accuracy_score(true_labels_array, predicted_labels_array)
# print(f"\nAccuracy After Merging: {accuracy:.4f}")

# %%
# import pandas as pd
# import numpy as np
# from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# # Assuming 'merged_cm_df' is your merged confusion matrix DataFrame
# # and 'unique_groups' is a list of group labels

# # Flatten the confusion matrix to obtain true and predicted labels
# true_labels_list = []
# predicted_labels_list = []

# for actual_group in merged_cm_df.index:
#     for predicted_group in merged_cm_df.columns:
#         count = merged_cm_df.at[actual_group, predicted_group]
#         if count > 0:
#             true_labels_list.extend([actual_group] * count)
#             predicted_labels_list.extend([predicted_group] * count)

# # Convert lists to numpy arrays
# true_labels_array = np.array(true_labels_list)
# predicted_labels_array = np.array(predicted_labels_list)

# # Calculate accuracy
# accuracy = accuracy_score(true_labels_array, predicted_labels_array)
# print(f"\nAccuracy After Merging: {accuracy:.4f}")

# # Calculate precision, recall, f1-score for each group
# precision, recall, f1, support = precision_recall_fscore_support(
#     true_labels_array,
#     predicted_labels_array,
#     labels=unique_groups,
#     zero_division=0
# )

# # Create a DataFrame for the metrics
# metrics_df = pd.DataFrame({
#     'Group': unique_groups,
#     'Precision': precision,
#     'Recall': recall,
#     'F1-Score': f1,
#     'Support': support
# })

# # Calculate macro and weighted averages
# macro_precision = np.mean(precision)
# macro_recall = np.mean(recall)
# macro_f1 = np.mean(f1)

# weighted_precision = np.average(precision, weights=support)
# weighted_recall = np.average(recall, weights=support)
# weighted_f1 = np.average(f1, weights=support)

# # Create a DataFrame for the averages
# averages = pd.DataFrame({
#     'Group': ['Macro Average', 'Weighted Average'],
#     'Precision': [macro_precision, weighted_precision],
#     'Recall': [macro_recall, weighted_recall],
#     'F1-Score': [macro_f1, weighted_f1],
#     'Support': [merged_cm_df.values.sum(), merged_cm_df.values.sum()]
# })

# # Concatenate the averages to metrics_df
# metrics_df = pd.concat([metrics_df, averages], ignore_index=True)

# print("\nPerformance Metrics After Merging:")
# print(metrics_df)

# %%
# print("\nPerformance Metrics After Merging:")
# print(metrics_df)

# # Save the merged confusion matrix as CSV
# merged_cm_csv_path = os.path.join(save_path, "merged_confusion_matrix.csv")
# merged_cm_df.to_csv(merged_cm_csv_path)
# print(f"\nMerged Confusion Matrix saved at: {merged_cm_csv_path}")

# # Save the performance metrics as CSV
# metrics_csv_path = os.path.join(save_path, "performance_metrics_after_merging.csv")
# metrics_df.to_csv(metrics_csv_path, index=False)
# print(f"Performance Metrics saved at: {metrics_csv_path}")

# # Optional: Save the merged confusion matrix as an image
# plt.figure(figsize=(20,18))  # Adjust size as needed
# sns.heatmap(merged_cm_df, annot=True, fmt='d', cmap='Blues', linewidths=.5)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.title('Merged Confusion Matrix')
# plt.tight_layout()
# image_file_path = os.path.join(save_path, "merged_confusion_matrix.png")
# plt.savefig(image_file_path)
# plt.close()
# print(f"Merged Confusion Matrix image saved at: {image_file_path}")

# # Optional: Normalize and save the normalized confusion matrix
# normalized_cm_df = merged_cm_df.div(merged_cm_df.sum(axis=1), axis=0).fillna(0)

# print("\nNormalized Merged Confusion Matrix:")
# print(normalized_cm_df)

# # Save the normalized confusion matrix as CSV
# normalized_cm_csv_path = os.path.join(save_path, "merged_confusion_matrix_normalized.csv")
# normalized_cm_df.to_csv(normalized_cm_csv_path)
# print(f"\nNormalized Confusion Matrix saved at: {normalized_cm_csv_path}")

# # Plot the normalized confusion matrix
# plt.figure(figsize=(20,18))
# sns.heatmap(normalized_cm_df, annot=True, fmt=".2f", cmap='Blues', linewidths=.5)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.title('Normalized Merged Confusion Matrix')
# plt.tight_layout()
# normalized_image_file_path = os.path.join(save_path, "merged_confusion_matrix_normalized.png")
# plt.savefig(normalized_image_file_path)
# plt.close()
# print(f"Normalized Confusion Matrix image saved at: {normalized_image_file_path}")

# # Analyze misclassifications
# # Remove the diagonal to focus on misclassifications
# cm_no_diag = merged_cm_df.copy()
# np.fill_diagonal(cm_no_diag.values, 0)

# # Melt the DataFrame to have a long-form table
# confusion_melted = cm_no_diag.reset_index().melt(id_vars='index', var_name='Predicted', value_name='Count')
# confusion_melted = confusion_melted.rename(columns={'index': 'Actual'})

# # Sort by Count descending to identify top misclassifications
# top_misclassifications = confusion_melted.sort_values(by='Count', ascending=False)

# # Display top 10 misclassifications
# print("\nTop 10 Misclassifications:")
# print(top_misclassifications.head(10))

# # Save the top misclassifications to the report
# report_file_path = os.path.join(save_path, "confusion_matrices.txt")
# with open(report_file_path, "a") as f:
#     f.write("\nTop 10 Misclassifications After Merging:\n")
#     f.write(top_misclassifications.head(10).to_string(index=False))

# # Detect mutual confusions: A -> B and B -> A
# mutual_confusions = []
# for actual in merged_cm_df.index:
#     predicted = merged_cm_df.loc[actual].idxmax()
#     if actual != predicted:
#         predicted_top = merged_cm_df.loc[predicted].idxmax()
#         if predicted_top == actual:
#             pair = tuple(sorted([actual, predicted]))
#             if pair not in mutual_confusions:
#                 mutual_confusions.append(pair)

# print("\nMutual Confusions (Pairs of Diseases):")
# for pair in mutual_confusions:
#     print(f"{pair[0]} <--> {pair[1]}")

# # Save mutual confusions to the report
# with open(report_file_path, "a") as f:
#     f.write("\nMutual Confusions (Pairs of Diseases):\n")
#     if mutual_confusions:
#         for pair in mutual_confusions:
#             f.write(f"{pair[0]} <--> {pair[1]}\n")
#     else:
#         f.write("No mutual confusions detected.\n")

# %%
def get_model_size(model):
    """
    Calculate model size in different ways:
    - Number of parameters (total and trainable)
    - Memory size in MB
    """
    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    # Calculate memory size (assuming float32 = 4 bytes per parameter)
    param_size_mb = total_params * 4 / (1024 ** 2)
    
    # Calculate buffer size (for BatchNorm running stats, etc.)
    buffer_size = sum(b.numel() for b in model.buffers())
    buffer_size_mb = buffer_size * 4 / (1024 ** 2)
    
    total_size_mb = param_size_mb + buffer_size_mb
    
    return {
        'total_params': total_params,
        'trainable_params': trainable_params,
        'param_size_mb': param_size_mb,
        'buffer_size_mb': buffer_size_mb,
        'total_size_mb': total_size_mb
    }

# Measure all models (make sure they are instantiated first)
models = {
    'ConvFcClassifier': conv_fc_classifier,
    'AttentionConvFcClassifier': atten_conv_fc_classifier,
    'LightweightConvFcClassifier': light_conv_fc_classifier,
    'SharedAdaptiveConvClassifier': ams_classifier
}

print(f"{'Model':<35} {'Total Params':>15} {'Trainable':>15} {'Size (MB)':>12}")
print("-" * 80)

for name, model in models.items():
    info = get_model_size(model)
    print(f"{name:<35} {info['total_params']:>15,} {info['trainable_params']:>15,} {info['total_size_mb']:>12.3f}")
# Out:
# Model                                  Total Params       Trainable    Size (MB)
# --------------------------------------------------------------------------------
# ConvFcClassifier                            527,124         527,124        2.022
# AttentionConvFcClassifier                 1,608,468       1,608,468        6.147
# LightweightConvFcClassifier                 396,052         396,052        1.522
# SharedAdaptiveConvClassifier              1,239,412       1,239,412        4.735
